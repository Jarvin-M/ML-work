# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import os

# %%
cuda = True
cnt = 0
lr = 1e-4
batch_size = 4

nc = 3 # number of channels
nz = 64 # size of latent vector
ngf = 64 # decoder (generator) filter factor
ndf = 64 # encoder filter factor
h_dim = 128 # discriminator hidden size
lam = 1 # regulization coefficient

# %%
class Decoder(nn.Module):
        def __init__(self):
            super(Decoder, self).__init__()
            self.main = [
                # input is Z, going into a convolution
                nn.ConvTranspose2d(     nz, ngf * 8, 4, 1, 0, bias=False),
                nn.BatchNorm2d(ngf * 8),
                nn.ReLU(True),
                # state size. (ngf*8) x 4 x 4
                nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ngf * 4),
                nn.ReLU(True),
                # state size. (ngf*4) x 8 x 8
                nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ngf * 2),
                nn.ReLU(True),
                # state size. (ngf*2) x 16 x 16
                nn.ConvTranspose2d(ngf * 2,     ngf, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ngf),
                nn.ReLU(True),
                # state size. (ngf) x 32 x 32
                nn.ConvTranspose2d(    ngf,      nc, 4, 2, 1, bias=False),
                nn.Sigmoid()
                # state size. (nc) x 64 x 64
            ]
            for idx, module in enumerate(self.main):
                self.add_module(str(idx), module)

        def forward(self, x):
            for layer in self.main:
                x = layer(x)
            return x

class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        self.main = [
            # input is (nc) x 64 x 64
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*2) x 16 x 16
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*4) x 8 x 8
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*8) x 4 x 4
            nn.Conv2d(ndf * 8, nz, 4, 1, 0, bias=False),
        ]

        for idx, module in enumerate(self.main):
            self.add_module(str(idx), module)

    def forward(self, x):
        for layer in self.main:
            x = layer(x)
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = [
            nn.Linear(nz, h_dim),
            nn.ReLU(),
            nn.Linear(h_dim, 1),
            nn.Sigmoid()
        ]
        for idx, module in enumerate(self.main):
            self.add_module(str(idx), module)
    def forward(self, x):
        for layer in self.main:
            x = layer(x)
        return x

# %%
number_classes = 15
current_directory = os.getcwd()

# %%
for x in range(1, number_classes):
    data_path = current_directory + '\\swedish_data\\' + str(x) + '\\'
    print(data_path)
    transform = transforms.Compose([
        transforms.Resize(64),
        transforms.CenterCrop(64),
        transforms.ToTensor(),
        # transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
    ])
    
    dataset = datasets.ImageFolder(data_path, transform)
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=20, drop_last=True)
    out_dir = data_path + 'out'
    os.mkdir(out_dir)
    
    Q = Encoder()
    P = Decoder()
    D = Discriminator()

    if cuda:
        Q = Q.cuda()
        P = P.cuda()
        D = D.cuda()

    def reset_grad():
        Q.zero_grad()
        P.zero_grad()
        D.zero_grad()

    Q_solver = optim.Adam(Q.parameters(), lr=lr)
    P_solver = optim.Adam(P.parameters(), lr=lr)
    D_solver = optim.Adam(D.parameters(), lr=lr*0.1)
    
    for it in range(100):
        for batch_idx, batch_item in enumerate(data_loader):
            #X = sample_X(mb_size)
            """ Reconstruction phase """
            X = Variable(batch_item[0])
            if cuda:
                X = X.cuda()

            z_sample = Q(X)

            X_sample = P(z_sample)
            recon_loss = F.mse_loss(X_sample, X)

            recon_loss.backward()
            P_solver.step()
            Q_solver.step()
            reset_grad()

            """ Regularization phase """
            # Discriminator
            for _ in range(5):
                z_real = Variable(torch.randn(batch_size, nz))
                if cuda:
                    z_real = z_real.cuda()

                z_fake = Q(X).view(batch_size,-1)

                D_real = D(z_real)
                D_fake = D(z_fake)

                #D_loss = -torch.mean(torch.log(D_real) + torch.log(1 - D_fake))
                D_loss = -(torch.mean(D_real) - torch.mean(D_fake))

                D_loss.backward()
                D_solver.step()

                # Weight clipping
                for p in D.parameters():
                    p.data.clamp_(-0.01, 0.01)

                reset_grad()

            # Generator
            z_fake = Q(X).view(batch_size,-1)
            D_fake = D(z_fake)

            #G_loss = -torch.mean(torch.log(D_fake))
            G_loss = -torch.mean(D_fake)

            G_loss.backward()
            Q_solver.step()
            reset_grad()

            if batch_idx % 10 == 0:
                print('Iter-{}; D_loss: {:.4}; G_loss: {:.4}; recon_loss: {:.4}'
                      .format(batch_idx, D_loss.item(), G_loss.item(), recon_loss.item()))
                torch.save(Q, out_dir + "\\Q_latest.pth")
                torch.save(P, out_dir + "\\P_latest.pth")
                torch.save(D, out_dir + "\\D_latest.pth")

            # Print and plot every now and then
            if batch_idx % 100 == 0:

                z_real = z_real.unsqueeze(2).unsqueeze(3) # add 2 dimensions
                if cnt % 2 == 0:
                    samples = P(z_real) # Generated
                else:
                    samples = X_sample # Reconstruction
                #samples = X_sample
                if cuda:
                    samples = samples.cpu()
                samples = samples.data.numpy()[:16]

                fig = plt.figure(figsize=(4, 4))
                gs = gridspec.GridSpec(4, 4)
                gs.update(wspace=0.05, hspace=0.05)

                for i, sample in enumerate(samples):
                    ax = plt.subplot(gs[i])
                    plt.axis('off')
                    ax.set_xticklabels([])
                    ax.set_yticklabels([])
                    ax.set_aspect('equal')
                    sample = np.swapaxes(sample,0,2)
                    plt.imshow(sample)


                if not os.path.exists(out_dir):
                    os.makedirs(out_dir)

                plt.savefig('{}/{}.png'
                            .format(out_dir,str(cnt).zfill(3)), bbox_inches='tight')
                cnt += 1
                plt.close(fig)
# Out:
# C:\Users\Parth Pankaj Tiwary\Desktop\examples-master\waae\swedish_data\1\
# Iter-0; D_loss: 0.0001283; G_loss: -0.4966; recon_loss: 0.1274
# C:\Users\Parth Pankaj Tiwary\Anaconda2\envs\torch\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type Encoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\Parth Pankaj Tiwary\Anaconda2\envs\torch\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type Decoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\Parth Pankaj Tiwary\Anaconda2\envs\torch\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type Discriminator. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Iter-10; D_loss: 0.009878; G_loss: -0.5073; recon_loss: 0.09019
# Iter-0; D_loss: 0.01469; G_loss: -0.512; recon_loss: 0.07822
# Iter-10; D_loss: 0.01574; G_loss: -0.5141; recon_loss: 0.06801
# Iter-0; D_loss: 0.009383; G_loss: -0.5068; recon_loss: 0.07664
# Iter-10; D_loss: -0.00136; G_loss: -0.4964; recon_loss: 0.05659
# Iter-0; D_loss: 0.004748; G_loss: -0.502; recon_loss: 0.06798
# Iter-10; D_loss: 0.007554; G_loss: -0.5054; recon_loss: 0.05252
# Iter-0; D_loss: 0.002973; G_loss: -0.5006; recon_loss: 0.05115
# Iter-10; D_loss: -0.002648; G_loss: -0.4942; recon_loss: 0.04905
# Iter-0; D_loss: 0.001428; G_loss: -0.4979; recon_loss: 0.03982
# Iter-10; D_loss: 0.002143; G_loss: -0.4995; recon_loss: 0.03065
# Iter-0; D_loss: 0.00334; G_loss: -0.4999; recon_loss: 0.03815
# Iter-10; D_loss: 0.0004434; G_loss: -0.4973; recon_loss: 0.02675
# Iter-0; D_loss: -0.0002833; G_loss: -0.4964; recon_loss: 0.03034
# Iter-10; D_loss: -0.0006623; G_loss: -0.4969; recon_loss: 0.02408
# Iter-0; D_loss: 0.001038; G_loss: -0.4978; recon_loss: 0.02306
# Iter-10; D_loss: 0.001831; G_loss: -0.4988; recon_loss: 0.02242
# Iter-0; D_loss: 0.0002521; G_loss: -0.4969; recon_loss: 0.02041
# Iter-10; D_loss: -0.0004445; G_loss: -0.496; recon_loss: 0.02341
# Iter-0; D_loss: 0.0008936; G_loss: -0.4975; recon_loss: 0.0194
# Iter-10; D_loss: 0.002148; G_loss: -0.4987; recon_loss: 0.01803
# Iter-0; D_loss: 0.001205; G_loss: -0.4974; recon_loss: 0.01901
# Iter-10; D_loss: -0.002615; G_loss: -0.4935; recon_loss: 0.02138
# Iter-0; D_loss: -0.001595; G_loss: -0.4944; recon_loss: 0.01664
# Iter-10; D_loss: 0.000855; G_loss: -0.4972; recon_loss: 0.01419
# Iter-0; D_loss: 0.001011; G_loss: -0.498; recon_loss: 0.01245
# Iter-10; D_loss: 0.002626; G_loss: -0.4983; recon_loss: 0.01386
# Iter-0; D_loss: 0.001166; G_loss: -0.4976; recon_loss: 0.01784
# Iter-10; D_loss: -0.001276; G_loss: -0.495; recon_loss: 0.01475
# Iter-0; D_loss: -0.0007901; G_loss: -0.496; recon_loss: 0.01367
# Iter-10; D_loss: 0.0007812; G_loss: -0.4969; recon_loss: 0.01026
# Iter-0; D_loss: 0.0007331; G_loss: -0.4959; recon_loss: 0.01492
# Iter-10; D_loss: 0.0002581; G_loss: -0.4962; recon_loss: 0.01051
# Iter-0; D_loss: -0.001325; G_loss: -0.4949; recon_loss: 0.02012
# Iter-10; D_loss: -0.0009453; G_loss: -0.4952; recon_loss: 0.01214
# Iter-0; D_loss: -0.001114; G_loss: -0.4956; recon_loss: 0.01028
# Iter-10; D_loss: -0.000158; G_loss: -0.496; recon_loss: 0.01237
# Iter-0; D_loss: -0.000365; G_loss: -0.4958; recon_loss: 0.01285
# Iter-10; D_loss: -0.0001235; G_loss: -0.4958; recon_loss: 0.009883
# Iter-0; D_loss: -0.0004529; G_loss: -0.4959; recon_loss: 0.01
# Iter-10; D_loss: 0.0006248; G_loss: -0.4964; recon_loss: 0.01328
# Iter-0; D_loss: 0.0008686; G_loss: -0.4968; recon_loss: 0.008097
# Iter-10; D_loss: -0.0006828; G_loss: -0.4963; recon_loss: 0.009549
# Iter-0; D_loss: -0.000745; G_loss: -0.4952; recon_loss: 0.008855
# Iter-10; D_loss: -0.001732; G_loss: -0.4945; recon_loss: 0.01188
# Iter-0; D_loss: -0.001732; G_loss: -0.4954; recon_loss: 0.0116
# Iter-10; D_loss: 0.001262; G_loss: -0.4966; recon_loss: 0.008571
# Iter-0; D_loss: -0.0006454; G_loss: -0.4957; recon_loss: 0.01063
# Iter-10; D_loss: -0.0007147; G_loss: -0.4954; recon_loss: 0.008004
# Iter-0; D_loss: -0.001113; G_loss: -0.4954; recon_loss: 0.009335
# Iter-10; D_loss: -0.0003237; G_loss: -0.4955; recon_loss: 0.008622
# Iter-0; D_loss: 0.0003119; G_loss: -0.4959; recon_loss: 0.007191
# Iter-10; D_loss: 3.883e-05; G_loss: -0.4962; recon_loss: 0.006884
# Iter-0; D_loss: -0.0003699; G_loss: -0.4963; recon_loss: 0.008729
# Iter-10; D_loss: 0.001154; G_loss: -0.4973; recon_loss: 0.007771
# Iter-0; D_loss: 0.0005648; G_loss: -0.4973; recon_loss: 0.009904
# Iter-10; D_loss: 0.0004505; G_loss: -0.4961; recon_loss: 0.008284
# Iter-0; D_loss: -0.0006679; G_loss: -0.4955; recon_loss: 0.009171
# Iter-10; D_loss: -0.0008944; G_loss: -0.4951; recon_loss: 0.007301
# Iter-0; D_loss: 0.0004363; G_loss: -0.4964; recon_loss: 0.007289
# Iter-10; D_loss: -0.0009493; G_loss: -0.4956; recon_loss: 0.007839
# Iter-0; D_loss: 9.376e-05; G_loss: -0.4963; recon_loss: 0.008463
# Iter-10; D_loss: 0.0008799; G_loss: -0.4964; recon_loss: 0.006399
# Iter-0; D_loss: 0.0007984; G_loss: -0.4967; recon_loss: 0.007016
# Iter-10; D_loss: 0.0007497; G_loss: -0.4969; recon_loss: 0.005985
# Iter-0; D_loss: -0.0009265; G_loss: -0.496; recon_loss: 0.006062
# Iter-10; D_loss: -0.0002409; G_loss: -0.4959; recon_loss: 0.005637
# Iter-0; D_loss: 0.0004826; G_loss: -0.4967; recon_loss: 0.007604
# Iter-10; D_loss: 0.0007572; G_loss: -0.4967; recon_loss: 0.006291
# Iter-0; D_loss: 0.001301; G_loss: -0.4969; recon_loss: 0.005568
# Iter-10; D_loss: 0.0001651; G_loss: -0.4966; recon_loss: 0.006427
# Iter-0; D_loss: -0.0003875; G_loss: -0.4963; recon_loss: 0.005826
# Iter-10; D_loss: 6.443e-05; G_loss: -0.4961; recon_loss: 0.006089
# Iter-0; D_loss: 0.0006043; G_loss: -0.4966; recon_loss: 0.005413
# Iter-10; D_loss: 0.0003492; G_loss: -0.4968; recon_loss: 0.004736
# Iter-0; D_loss: -3.761e-05; G_loss: -0.4964; recon_loss: 0.005779
# Iter-10; D_loss: 1.368e-05; G_loss: -0.4966; recon_loss: 0.006511
# Iter-0; D_loss: -0.0003124; G_loss: -0.496; recon_loss: 0.007183
# Iter-10; D_loss: -0.0005002; G_loss: -0.4964; recon_loss: 0.005539
# Iter-0; D_loss: -0.0004025; G_loss: -0.496; recon_loss: 0.006816
# Iter-10; D_loss: 0.0004768; G_loss: -0.4966; recon_loss: 0.006483
# Iter-0; D_loss: 0.0005081; G_loss: -0.4963; recon_loss: 0.005209
# Iter-10; D_loss: -0.000301; G_loss: -0.4961; recon_loss: 0.005699
# Iter-0; D_loss: -1.353e-05; G_loss: -0.4963; recon_loss: 0.005624
# Iter-10; D_loss: 0.0005828; G_loss: -0.4967; recon_loss: 0.005943
# Iter-0; D_loss: -0.0002313; G_loss: -0.4966; recon_loss: 0.007276
# Iter-10; D_loss: -0.0004444; G_loss: -0.4961; recon_loss: 0.005621
# Iter-0; D_loss: -0.0004186; G_loss: -0.4958; recon_loss: 0.005912
# Iter-10; D_loss: 0.0001456; G_loss: -0.4963; recon_loss: 0.004477
# Iter-0; D_loss: 0.0001898; G_loss: -0.4965; recon_loss: 0.005261
# Iter-10; D_loss: 0.0001643; G_loss: -0.4964; recon_loss: 0.005011
# Iter-0; D_loss: -0.0003249; G_loss: -0.4963; recon_loss: 0.00497
# Iter-10; D_loss: 2.959e-05; G_loss: -0.4963; recon_loss: 0.005562
# Iter-0; D_loss: -0.0002325; G_loss: -0.4962; recon_loss: 0.005059
# Iter-10; D_loss: -0.0003121; G_loss: -0.4963; recon_loss: 0.006014
# Iter-0; D_loss: 0.0005102; G_loss: -0.4969; recon_loss: 0.005128
# Iter-10; D_loss: -0.0003422; G_loss: -0.4966; recon_loss: 0.004676
# Iter-0; D_loss: -0.0008907; G_loss: -0.4958; recon_loss: 0.005156
# Iter-10; D_loss: -0.0003079; G_loss: -0.4963; recon_loss: 0.004478
# Iter-0; D_loss: -0.0004381; G_loss: -0.4965; recon_loss: 0.004481
# Iter-10; D_loss: -0.0001708; G_loss: -0.4965; recon_loss: 0.005308
# Iter-0; D_loss: -0.0004341; G_loss: -0.4962; recon_loss: 0.00551
# Iter-10; D_loss: -0.0002939; G_loss: -0.4964; recon_loss: 0.005983
# Iter-0; D_loss: -0.0007642; G_loss: -0.4963; recon_loss: 0.004497
# Iter-10; D_loss: -0.0004178; G_loss: -0.4966; recon_loss: 0.004333
# Iter-0; D_loss: -0.0002202; G_loss: -0.4967; recon_loss: 0.004612
# Iter-10; D_loss: -1.037e-05; G_loss: -0.4968; recon_loss: 0.004374
# Iter-0; D_loss: 8.452e-05; G_loss: -0.4967; recon_loss: 0.004281
# Iter-10; D_loss: 6.497e-06; G_loss: -0.4971; recon_loss: 0.004195
# Iter-0; D_loss: 0.0004898; G_loss: -0.4968; recon_loss: 0.004583
# Iter-10; D_loss: -6.288e-06; G_loss: -0.4971; recon_loss: 0.004355
# Iter-0; D_loss: -0.0005169; G_loss: -0.4965; recon_loss: 0.006087
# Iter-10; D_loss: -0.0002824; G_loss: -0.4963; recon_loss: 0.006504
# Iter-0; D_loss: -0.00114; G_loss: -0.4956; recon_loss: 0.005013
# Iter-10; D_loss: -0.0003778; G_loss: -0.4964; recon_loss: 0.004728
# Iter-0; D_loss: 0.0001762; G_loss: -0.4972; recon_loss: 0.004163
# Iter-10; D_loss: -0.0007931; G_loss: -0.4962; recon_loss: 0.00437
# Iter-0; D_loss: -0.0005026; G_loss: -0.4962; recon_loss: 0.005195
# Iter-10; D_loss: 0.000478; G_loss: -0.4976; recon_loss: 0.004473
# Iter-0; D_loss: 0.0006856; G_loss: -0.4978; recon_loss: 0.004127
# Iter-10; D_loss: -0.000628; G_loss: -0.4967; recon_loss: 0.004775
# Iter-0; D_loss: -0.0006937; G_loss: -0.496; recon_loss: 0.004322
# Iter-10; D_loss: -0.0002854; G_loss: -0.4969; recon_loss: 0.004633
# Iter-0; D_loss: -0.0001614; G_loss: -0.4975; recon_loss: 0.003765
# Iter-10; D_loss: -0.0002937; G_loss: -0.4973; recon_loss: 0.004196
# Iter-0; D_loss: -0.0006829; G_loss: -0.4967; recon_loss: 0.004448
# Iter-10; D_loss: -0.0003376; G_loss: -0.4967; recon_loss: 0.003917
# Iter-0; D_loss: 3.105e-05; G_loss: -0.4969; recon_loss: 0.005287
# Iter-10; D_loss: 0.0001315; G_loss: -0.4975; recon_loss: 0.004105
# Iter-0; D_loss: -0.000497; G_loss: -0.4969; recon_loss: 0.004085
# Iter-10; D_loss: -0.0005092; G_loss: -0.4972; recon_loss: 0.003821
# Iter-0; D_loss: -0.000347; G_loss: -0.4973; recon_loss: 0.004724
# Iter-10; D_loss: -0.0006266; G_loss: -0.4972; recon_loss: 0.003995
# Iter-0; D_loss: -0.0007555; G_loss: -0.4971; recon_loss: 0.003855
# Iter-10; D_loss: -0.0002241; G_loss: -0.4974; recon_loss: 0.005077
# Iter-0; D_loss: -0.0004602; G_loss: -0.4975; recon_loss: 0.0043
# Iter-10; D_loss: -4.938e-05; G_loss: -0.4979; recon_loss: 0.004736
# Iter-0; D_loss: -0.001349; G_loss: -0.4965; recon_loss: 0.004249
# Iter-10; D_loss: -0.0007824; G_loss: -0.4968; recon_loss: 0.004797
# Iter-0; D_loss: -0.0004979; G_loss: -0.497; recon_loss: 0.004856
# Iter-10; D_loss: -0.000125; G_loss: -0.4976; recon_loss: 0.003703
# Iter-0; D_loss: -0.0003712; G_loss: -0.498; recon_loss: 0.004371
# Iter-10; D_loss: -0.0007997; G_loss: -0.4973; recon_loss: 0.003944
# Iter-0; D_loss: -0.0005096; G_loss: -0.4968; recon_loss: 0.004382
# Iter-10; D_loss: -0.0003923; G_loss: -0.4974; recon_loss: 0.004974
# Iter-0; D_loss: 0.0001477; G_loss: -0.4981; recon_loss: 0.003991
# Iter-10; D_loss: 0.0003495; G_loss: -0.4982; recon_loss: 0.00327
# Iter-0; D_loss: 0.0002577; G_loss: -0.4981; recon_loss: 0.004126
# Iter-10; D_loss: -0.0004964; G_loss: -0.4977; recon_loss: 0.004014
# Iter-0; D_loss: -0.0004006; G_loss: -0.4973; recon_loss: 0.005077
# Iter-10; D_loss: -0.0004854; G_loss: -0.4976; recon_loss: 0.003939
# Iter-0; D_loss: -0.0006725; G_loss: -0.4976; recon_loss: 0.003712
# Iter-10; D_loss: -0.00121; G_loss: -0.4976; recon_loss: 0.003962
# Iter-0; D_loss: -0.0003041; G_loss: -0.4984; recon_loss: 0.003536
# Iter-10; D_loss: -0.0003802; G_loss: -0.4984; recon_loss: 0.004588
# Iter-0; D_loss: -0.000313; G_loss: -0.498; recon_loss: 0.003807
# Iter-10; D_loss: -0.0002249; G_loss: -0.4976; recon_loss: 0.003501
# Iter-0; D_loss: -0.0005039; G_loss: -0.4977; recon_loss: 0.006018
# Iter-10; D_loss: -0.0003738; G_loss: -0.4979; recon_loss: 0.00418
# Iter-0; D_loss: -0.0005859; G_loss: -0.4982; recon_loss: 0.003779
# Iter-10; D_loss: -0.0001048; G_loss: -0.4981; recon_loss: 0.004033
# Iter-0; D_loss: -0.0008279; G_loss: -0.4981; recon_loss: 0.003855
# Iter-10; D_loss: -0.001348; G_loss: -0.4976; recon_loss: 0.003366
# Iter-0; D_loss: 0.0001607; G_loss: -0.4983; recon_loss: 0.003717
# Iter-10; D_loss: 0.0003111; G_loss: -0.4991; recon_loss: 0.004139
# Iter-0; D_loss: 0.0002501; G_loss: -0.4988; recon_loss: 0.004888
# Iter-10; D_loss: -0.000392; G_loss: -0.4981; recon_loss: 0.003693
# Iter-0; D_loss: -0.000762; G_loss: -0.4977; recon_loss: 0.003731
# Iter-10; D_loss: -0.00045; G_loss: -0.4984; recon_loss: 0.003468
# Iter-0; D_loss: 0.000258; G_loss: -0.4986; recon_loss: 0.003768
# Iter-10; D_loss: 0.0006512; G_loss: -0.499; recon_loss: 0.004803
# Iter-0; D_loss: -0.000587; G_loss: -0.4983; recon_loss: 0.003801
# Iter-10; D_loss: -0.001144; G_loss: -0.4982; recon_loss: 0.003411
# Iter-0; D_loss: -0.0003032; G_loss: -0.4986; recon_loss: 0.003384
# Iter-10; D_loss: -0.0002937; G_loss: -0.4987; recon_loss: 0.003616
# Iter-0; D_loss: -0.0002393; G_loss: -0.4989; recon_loss: 0.003617
# Iter-10; D_loss: 0.0005475; G_loss: -0.4995; recon_loss: 0.003225
# Iter-0; D_loss: -0.0006511; G_loss: -0.4987; recon_loss: 0.00325
# Iter-10; D_loss: -0.0002521; G_loss: -0.4987; recon_loss: 0.003816
# Iter-0; D_loss: -4.283e-05; G_loss: -0.4987; recon_loss: 0.003401
# Iter-10; D_loss: -0.001273; G_loss: -0.498; recon_loss: 0.003399
# Iter-0; D_loss: -0.001626; G_loss: -0.4979; recon_loss: 0.003472
# Iter-10; D_loss: 2.202e-05; G_loss: -0.4994; recon_loss: 0.003626
# Iter-0; D_loss: 0.0005793; G_loss: -0.4998; recon_loss: 0.005466
# Iter-10; D_loss: -0.000527; G_loss: -0.4981; recon_loss: 0.003637
# Iter-0; D_loss: -0.0006151; G_loss: -0.4984; recon_loss: 0.003918
# Iter-10; D_loss: 0.0007693; G_loss: -0.4996; recon_loss: 0.004121
# Iter-0; D_loss: -0.0003448; G_loss: -0.4989; recon_loss: 0.003179
# Iter-10; D_loss: -0.0004074; G_loss: -0.4987; recon_loss: 0.003383
# Iter-0; D_loss: -8.523e-05; G_loss: -0.4993; recon_loss: 0.004378
# Iter-10; D_loss: -0.0002395; G_loss: -0.4988; recon_loss: 0.003131
# Iter-0; D_loss: -0.0004694; G_loss: -0.4987; recon_loss: 0.003445
# Iter-10; D_loss: -0.0004462; G_loss: -0.4989; recon_loss: 0.00299
# Iter-0; D_loss: -0.0009934; G_loss: -0.4987; recon_loss: 0.003058
# Iter-10; D_loss: -0.0003091; G_loss: -0.4993; recon_loss: 0.003855
# Iter-0; D_loss: 0.0001652; G_loss: -0.4996; recon_loss: 0.003047
# Iter-10; D_loss: 0.0004108; G_loss: -0.4997; recon_loss: 0.003909
# Iter-0; D_loss: -3.144e-05; G_loss: -0.4993; recon_loss: 0.003866
# Iter-10; D_loss: 0.0004393; G_loss: -0.4994; recon_loss: 0.004576
# C:\Users\Parth Pankaj Tiwary\Desktop\examples-master\waae\swedish_data\2\
# Iter-0; D_loss: -0.001521; G_loss: -0.5012; recon_loss: 0.2038
# Iter-10; D_loss: 0.01215; G_loss: -0.5159; recon_loss: 0.1524
# Iter-0; D_loss: 0.0217; G_loss: -0.5246; recon_loss: 0.1342
# Iter-10; D_loss: 0.02115; G_loss: -0.5237; recon_loss: 0.1267
# Iter-0; D_loss: 0.01611; G_loss: -0.5186; recon_loss: 0.109
# Iter-10; D_loss: 0.008165; G_loss: -0.5111; recon_loss: 0.1048
# Iter-0; D_loss: 0.005897; G_loss: -0.5082; recon_loss: 0.09474
# Iter-10; D_loss: 0.002228; G_loss: -0.5047; recon_loss: 0.09277
# Iter-0; D_loss: 0.006895; G_loss: -0.5089; recon_loss: 0.08488
# Iter-10; D_loss: 0.009444; G_loss: -0.512; recon_loss: 0.08203
# Iter-0; D_loss: 0.004284; G_loss: -0.5067; recon_loss: 0.07583
# Iter-10; D_loss: -2.015e-05; G_loss: -0.502; recon_loss: 0.0749
# Iter-0; D_loss: 0.001345; G_loss: -0.5025; recon_loss: 0.0692
# Iter-10; D_loss: 0.001518; G_loss: -0.5032; recon_loss: 0.06605
# Iter-0; D_loss: -0.001564; G_loss: -0.4994; recon_loss: 0.06055
# Iter-10; D_loss: -0.004062; G_loss: -0.4964; recon_loss: 0.06307
# Iter-0; D_loss: -0.000475; G_loss: -0.5008; recon_loss: 0.06014
# Iter-10; D_loss: 0.004122; G_loss: -0.5055; recon_loss: 0.05632
# Iter-0; D_loss: 0.003365; G_loss: -0.5045; recon_loss: 0.05341
# Iter-10; D_loss: -0.002978; G_loss: -0.498; recon_loss: 0.05216
# Iter-0; D_loss: -0.006845; G_loss: -0.4935; recon_loss: 0.0477
# Iter-10; D_loss: -0.001786; G_loss: -0.4991; recon_loss: 0.04997
# Iter-0; D_loss: 0.002291; G_loss: -0.5029; recon_loss: 0.04694
# Iter-10; D_loss: 0.002116; G_loss: -0.5032; recon_loss: 0.04513
# Iter-0; D_loss: 0.000947; G_loss: -0.5016; recon_loss: 0.04369
# Iter-10; D_loss: 0.0001461; G_loss: -0.4999; recon_loss: 0.04305
# Iter-0; D_loss: -0.002631; G_loss: -0.4978; recon_loss: 0.04033
# Iter-10; D_loss: -0.0007474; G_loss: -0.4994; recon_loss: 0.04007
# Iter-0; D_loss: -0.0008607; G_loss: -0.4993; recon_loss: 0.03789
# Iter-10; D_loss: -0.000222; G_loss: -0.4993; recon_loss: 0.04183
# Iter-0; D_loss: -0.001744; G_loss: -0.4985; recon_loss: 0.03557
# Iter-10; D_loss: -0.0009013; G_loss: -0.4994; recon_loss: 0.03536
# Iter-0; D_loss: -0.001384; G_loss: -0.4989; recon_loss: 0.03814
# Iter-10; D_loss: -0.001686; G_loss: -0.4986; recon_loss: 0.03587
# Iter-0; D_loss: -0.002006; G_loss: -0.4975; recon_loss: 0.03226
# Iter-10; D_loss: -0.002881; G_loss: -0.4973; recon_loss: 0.03122
# Iter-0; D_loss: -0.002055; G_loss: -0.4981; recon_loss: 0.03105
# Iter-10; D_loss: -0.002649; G_loss: -0.4975; recon_loss: 0.03254
# Iter-0; D_loss: -0.0001667; G_loss: -0.4998; recon_loss: 0.0271
# Iter-10; D_loss: -2.316e-05; G_loss: -0.4996; recon_loss: 0.03394
# Iter-0; D_loss: -0.0001897; G_loss: -0.4996; recon_loss: 0.03211
# Iter-10; D_loss: 0.0002983; G_loss: -0.5003; recon_loss: 0.03049
# Iter-0; D_loss: -0.001186; G_loss: -0.4992; recon_loss: 0.02829
# Iter-10; D_loss: -1.881e-05; G_loss: -0.4997; recon_loss: 0.03336
# Iter-0; D_loss: -0.003204; G_loss: -0.4965; recon_loss: 0.02799
# Iter-10; D_loss: -0.004329; G_loss: -0.4965; recon_loss: 0.02974
# Iter-0; D_loss: -0.001786; G_loss: -0.4974; recon_loss: 0.02885
# Iter-10; D_loss: -0.000237; G_loss: -0.4988; recon_loss: 0.03142
# Iter-0; D_loss: -0.001113; G_loss: -0.499; recon_loss: 0.02515
# Iter-10; D_loss: -0.0009553; G_loss: -0.4994; recon_loss: 0.02553
# Iter-0; D_loss: 0.0001789; G_loss: -0.5002; recon_loss: 0.02448
# Iter-10; D_loss: 0.000802; G_loss: -0.5008; recon_loss: 0.02207
# Iter-0; D_loss: 0.0004381; G_loss: -0.5002; recon_loss: 0.02259
# Iter-10; D_loss: 0.0005351; G_loss: -0.5; recon_loss: 0.02341
# Iter-0; D_loss: -0.0009683; G_loss: -0.5; recon_loss: 0.02535
# Iter-10; D_loss: -0.0001058; G_loss: -0.4997; recon_loss: 0.02471
# Iter-0; D_loss: -0.002843; G_loss: -0.4979; recon_loss: 0.01957
# Iter-10; D_loss: -0.0003577; G_loss: -0.4996; recon_loss: 0.02317
# Iter-0; D_loss: 0.0006011; G_loss: -0.5003; recon_loss: 0.02174
# Iter-10; D_loss: -6.098e-05; G_loss: -0.5002; recon_loss: 0.02396
# Iter-0; D_loss: -0.0002211; G_loss: -0.5004; recon_loss: 0.02477
# Iter-10; D_loss: -0.0005088; G_loss: -0.4997; recon_loss: 0.02858
# Iter-0; D_loss: -2.801e-05; G_loss: -0.4998; recon_loss: 0.02062
# Iter-10; D_loss: -0.0003877; G_loss: -0.5004; recon_loss: 0.02221
# Iter-0; D_loss: 0.0009018; G_loss: -0.5009; recon_loss: 0.02028
# Iter-10; D_loss: -0.001181; G_loss: -0.5; recon_loss: 0.02466
# Iter-0; D_loss: -0.0003709; G_loss: -0.4995; recon_loss: 0.0215
# Iter-10; D_loss: -8.523e-06; G_loss: -0.4998; recon_loss: 0.01712
# Iter-0; D_loss: -0.0002348; G_loss: -0.4999; recon_loss: 0.01763
# Iter-10; D_loss: 0.0006893; G_loss: -0.5005; recon_loss: 0.02243
# Iter-0; D_loss: 0.0002697; G_loss: -0.4999; recon_loss: 0.01771
# Iter-10; D_loss: -0.0002706; G_loss: -0.5004; recon_loss: 0.01754
# Iter-0; D_loss: 0.0006559; G_loss: -0.5004; recon_loss: 0.0198
# Iter-10; D_loss: -0.0008401; G_loss: -0.4995; recon_loss: 0.01806
# Iter-0; D_loss: -0.0002254; G_loss: -0.499; recon_loss: 0.01616
# Iter-10; D_loss: -0.001305; G_loss: -0.4992; recon_loss: 0.0165
# Iter-0; D_loss: -0.0004113; G_loss: -0.5; recon_loss: 0.01886
# Iter-10; D_loss: 0.0002463; G_loss: -0.5; recon_loss: 0.01667
# Iter-0; D_loss: 0.0006868; G_loss: -0.5011; recon_loss: 0.01676
# Iter-10; D_loss: 7.445e-05; G_loss: -0.5003; recon_loss: 0.01556
# Iter-0; D_loss: 0.0005047; G_loss: -0.5001; recon_loss: 0.01616
# Iter-10; D_loss: -0.0008481; G_loss: -0.4999; recon_loss: 0.01646
# Iter-0; D_loss: 0.0002187; G_loss: -0.5001; recon_loss: 0.01678
# Iter-10; D_loss: 0.0001903; G_loss: -0.5004; recon_loss: 0.01584
# Iter-0; D_loss: -0.0005912; G_loss: -0.4999; recon_loss: 0.02031
# Iter-10; D_loss: -0.001819; G_loss: -0.4988; recon_loss: 0.0162
# Iter-0; D_loss: -0.001663; G_loss: -0.4989; recon_loss: 0.01623
# Iter-10; D_loss: -0.000556; G_loss: -0.4998; recon_loss: 0.01933
# Iter-0; D_loss: -0.0005341; G_loss: -0.5; recon_loss: 0.01466
# Iter-10; D_loss: -0.001197; G_loss: -0.5002; recon_loss: 0.01763
# Iter-0; D_loss: -0.0003313; G_loss: -0.5004; recon_loss: 0.01473
# Iter-10; D_loss: 0.0003082; G_loss: -0.5005; recon_loss: 0.01586
# Iter-0; D_loss: -0.0001093; G_loss: -0.5011; recon_loss: 0.01401
# Iter-10; D_loss: 0.0006879; G_loss: -0.5013; recon_loss: 0.01488
# Iter-0; D_loss: 0.0002981; G_loss: -0.5012; recon_loss: 0.01344
# Iter-10; D_loss: -0.001134; G_loss: -0.4999; recon_loss: 0.01339
# Iter-0; D_loss: -0.0009083; G_loss: -0.4997; recon_loss: 0.01377
# Iter-10; D_loss: -0.0009207; G_loss: -0.4998; recon_loss: 0.01623
# Iter-0; D_loss: -0.0002993; G_loss: -0.5003; recon_loss: 0.01366
# Iter-10; D_loss: -0.000338; G_loss: -0.5007; recon_loss: 0.01554
# Iter-0; D_loss: -0.001141; G_loss: -0.5001; recon_loss: 0.01264
# Iter-10; D_loss: -0.001287; G_loss: -0.4997; recon_loss: 0.01247
# Iter-0; D_loss: -0.001425; G_loss: -0.4992; recon_loss: 0.01848
# Iter-10; D_loss: -0.000902; G_loss: -0.4999; recon_loss: 0.01604
# Iter-0; D_loss: -0.0002291; G_loss: -0.5003; recon_loss: 0.01327
# Iter-10; D_loss: -0.0006498; G_loss: -0.5002; recon_loss: 0.01352
# Iter-0; D_loss: -0.0003065; G_loss: -0.5004; recon_loss: 0.01331
# Iter-10; D_loss: -0.001402; G_loss: -0.4999; recon_loss: 0.01213
# Iter-0; D_loss: -0.001326; G_loss: -0.4999; recon_loss: 0.0134
# Iter-10; D_loss: -0.001387; G_loss: -0.5003; recon_loss: 0.01433
# Iter-0; D_loss: -0.0006495; G_loss: -0.5001; recon_loss: 0.01285
# Iter-10; D_loss: -0.0008035; G_loss: -0.5006; recon_loss: 0.01184
# Iter-0; D_loss: -0.0003121; G_loss: -0.5004; recon_loss: 0.01232
# Iter-10; D_loss: -0.0005619; G_loss: -0.5007; recon_loss: 0.01232
# Iter-0; D_loss: -0.0007663; G_loss: -0.5007; recon_loss: 0.01157
# Iter-10; D_loss: 8.315e-05; G_loss: -0.5006; recon_loss: 0.01053
# Iter-0; D_loss: 7.808e-06; G_loss: -0.5011; recon_loss: 0.01099
# Iter-10; D_loss: 7.164e-05; G_loss: -0.5007; recon_loss: 0.011
# Iter-0; D_loss: -0.0002463; G_loss: -0.5009; recon_loss: 0.01004
# Iter-10; D_loss: -0.0008656; G_loss: -0.5003; recon_loss: 0.01
# Iter-0; D_loss: -0.001425; G_loss: -0.4999; recon_loss: 0.01032
# Iter-10; D_loss: -0.001107; G_loss: -0.5003; recon_loss: 0.01154
# Iter-0; D_loss: -0.0005071; G_loss: -0.5001; recon_loss: 0.01199
# Iter-10; D_loss: -0.0007941; G_loss: -0.4999; recon_loss: 0.01124
# Iter-0; D_loss: -0.001404; G_loss: -0.4995; recon_loss: 0.01006
# Iter-10; D_loss: -0.000794; G_loss: -0.5002; recon_loss: 0.009197
# Iter-0; D_loss: -0.001024; G_loss: -0.5002; recon_loss: 0.008941
# Iter-10; D_loss: -0.0003258; G_loss: -0.5004; recon_loss: 0.009615
# Iter-0; D_loss: -0.001059; G_loss: -0.5003; recon_loss: 0.008182
# Iter-10; D_loss: -0.0001793; G_loss: -0.5004; recon_loss: 0.00884
# Iter-0; D_loss: -0.0009013; G_loss: -0.5003; recon_loss: 0.008751
# Iter-10; D_loss: -0.0003852; G_loss: -0.5007; recon_loss: 0.01034
# Iter-0; D_loss: -0.000379; G_loss: -0.5005; recon_loss: 0.008376
# Iter-10; D_loss: -0.0009448; G_loss: -0.5004; recon_loss: 0.008617
# Iter-0; D_loss: -0.0009192; G_loss: -0.5005; recon_loss: 0.007309
# Iter-10; D_loss: -0.001066; G_loss: -0.5002; recon_loss: 0.01106
# Iter-0; D_loss: -0.0007569; G_loss: -0.5001; recon_loss: 0.009827
# Iter-10; D_loss: -0.001091; G_loss: -0.5003; recon_loss: 0.007581
# Iter-0; D_loss: -0.000205; G_loss: -0.5004; recon_loss: 0.007489
# Iter-10; D_loss: -0.0004894; G_loss: -0.5004; recon_loss: 0.00756
# Iter-0; D_loss: -0.000248; G_loss: -0.5007; recon_loss: 0.007148
# Iter-10; D_loss: -0.0004173; G_loss: -0.5003; recon_loss: 0.008983
# Iter-0; D_loss: -0.001881; G_loss: -0.4997; recon_loss: 0.007963
# Iter-10; D_loss: -0.001298; G_loss: -0.4998; recon_loss: 0.008757
# Iter-0; D_loss: -0.0007251; G_loss: -0.5005; recon_loss: 0.007791
# Iter-10; D_loss: -0.00147; G_loss: -0.4996; recon_loss: 0.00752
# Iter-0; D_loss: -0.001382; G_loss: -0.4993; recon_loss: 0.007777
# Iter-10; D_loss: -0.001626; G_loss: -0.4993; recon_loss: 0.009106
# Iter-0; D_loss: -0.0006981; G_loss: -0.4999; recon_loss: 0.00763
# Iter-10; D_loss: -0.001073; G_loss: -0.4998; recon_loss: 0.007176
# Iter-0; D_loss: -0.001479; G_loss: -0.4993; recon_loss: 0.00718
# Iter-10; D_loss: -0.0005978; G_loss: -0.5; recon_loss: 0.006574
# Iter-0; D_loss: -0.001938; G_loss: -0.4989; recon_loss: 0.006502
# Iter-10; D_loss: -0.0007799; G_loss: -0.4995; recon_loss: 0.006913
# Iter-0; D_loss: -0.0003921; G_loss: -0.5; recon_loss: 0.006412
# Iter-10; D_loss: -0.0003294; G_loss: -0.5001; recon_loss: 0.005467
# Iter-0; D_loss: -0.0004134; G_loss: -0.5002; recon_loss: 0.005645
# Iter-10; D_loss: -0.001064; G_loss: -0.4998; recon_loss: 0.007466
# Iter-0; D_loss: -0.0009751; G_loss: -0.4995; recon_loss: 0.006194
# Iter-10; D_loss: -0.001292; G_loss: -0.4988; recon_loss: 0.0062
# Iter-0; D_loss: -0.001495; G_loss: -0.4992; recon_loss: 0.006298
# Iter-10; D_loss: 8.225e-06; G_loss: -0.5005; recon_loss: 0.006343
# Iter-0; D_loss: -0.0004202; G_loss: -0.4999; recon_loss: 0.005766
# Iter-10; D_loss: -0.001025; G_loss: -0.4992; recon_loss: 0.006463
# Iter-0; D_loss: -0.001607; G_loss: -0.4989; recon_loss: 0.005835
# Iter-10; D_loss: -0.0004194; G_loss: -0.5001; recon_loss: 0.005967
# Iter-0; D_loss: -0.001555; G_loss: -0.4994; recon_loss: 0.005914
# Iter-10; D_loss: -0.001051; G_loss: -0.499; recon_loss: 0.005543
# Iter-0; D_loss: -0.0004893; G_loss: -0.5002; recon_loss: 0.00576
# Iter-10; D_loss: -0.0007772; G_loss: -0.4996; recon_loss: 0.005747
# Iter-0; D_loss: -0.0007409; G_loss: -0.4995; recon_loss: 0.004522
# Iter-10; D_loss: -0.001202; G_loss: -0.4993; recon_loss: 0.005967
# Iter-0; D_loss: -0.001505; G_loss: -0.4991; recon_loss: 0.00475
# Iter-10; D_loss: -9.167e-05; G_loss: -0.4996; recon_loss: 0.006264
# Iter-0; D_loss: -0.0005591; G_loss: -0.4995; recon_loss: 0.005921
# Iter-10; D_loss: -0.0001057; G_loss: -0.5001; recon_loss: 0.004747
# Iter-0; D_loss: -0.001136; G_loss: -0.499; recon_loss: 0.004735
# Iter-10; D_loss: -0.0005561; G_loss: -0.4998; recon_loss: 0.005251
# Iter-0; D_loss: -0.001324; G_loss: -0.4995; recon_loss: 0.005017
# Iter-10; D_loss: -0.0002711; G_loss: -0.4999; recon_loss: 0.005188
# Iter-0; D_loss: -0.0009394; G_loss: -0.4992; recon_loss: 0.005359
# Iter-10; D_loss: -0.000649; G_loss: -0.4994; recon_loss: 0.005381
# Iter-0; D_loss: -0.0005788; G_loss: -0.4996; recon_loss: 0.004466
# Iter-10; D_loss: 0.0006517; G_loss: -0.4998; recon_loss: 0.006017
# Iter-0; D_loss: -0.0005425; G_loss: -0.4998; recon_loss: 0.004339
# Iter-10; D_loss: -7.48e-05; G_loss: -0.5001; recon_loss: 0.005124
# Iter-0; D_loss: -0.0003549; G_loss: -0.4999; recon_loss: 0.004559
# Iter-10; D_loss: -0.0009453; G_loss: -0.4996; recon_loss: 0.005507
# Iter-0; D_loss: -0.000959; G_loss: -0.4993; recon_loss: 0.004247
# Iter-10; D_loss: -0.0009578; G_loss: -0.4995; recon_loss: 0.00548
# Iter-0; D_loss: -0.0002481; G_loss: -0.4996; recon_loss: 0.004619
# Iter-10; D_loss: -0.001021; G_loss: -0.4993; recon_loss: 0.006359
# Iter-0; D_loss: -0.00062; G_loss: -0.4992; recon_loss: 0.005819
# Iter-10; D_loss: -0.0001479; G_loss: -0.5; recon_loss: 0.004683
# Iter-0; D_loss: -0.0003908; G_loss: -0.4997; recon_loss: 0.005005
# Iter-10; D_loss: -0.001231; G_loss: -0.499; recon_loss: 0.004514
# Iter-0; D_loss: -0.0009215; G_loss: -0.4992; recon_loss: 0.00509
# Iter-10; D_loss: -8.05e-05; G_loss: -0.4995; recon_loss: 0.005211
# Iter-0; D_loss: -0.0009271; G_loss: -0.4996; recon_loss: 0.00416
# Iter-10; D_loss: -0.0004532; G_loss: -0.4998; recon_loss: 0.005203
# C:\Users\Parth Pankaj Tiwary\Desktop\examples-master\waae\swedish_data\3\
# Iter-0; D_loss: 0.0001627; G_loss: -0.4973; recon_loss: 0.1569
# Iter-10; D_loss: 0.01873; G_loss: -0.5153; recon_loss: 0.1219
# Iter-0; D_loss: 0.02108; G_loss: -0.5184; recon_loss: 0.1017
# Iter-10; D_loss: 0.01522; G_loss: -0.512; recon_loss: 0.09218
# Iter-0; D_loss: 0.005447; G_loss: -0.5018; recon_loss: 0.07956
# Iter-10; D_loss: 0.0059; G_loss: -0.5018; recon_loss: 0.07286
# Iter-0; D_loss: 0.006501; G_loss: -0.503; recon_loss: 0.06806
# Iter-10; D_loss: 0.003203; G_loss: -0.5; recon_loss: 0.0644
# Iter-0; D_loss: 0.003695; G_loss: -0.5003; recon_loss: 0.06761
# Iter-10; D_loss: 0.003108; G_loss: -0.4995; recon_loss: 0.05448
# Iter-0; D_loss: 0.004609; G_loss: -0.5011; recon_loss: 0.05543
# Iter-10; D_loss: 0.001153; G_loss: -0.4975; recon_loss: 0.05134
# Iter-0; D_loss: -0.00157; G_loss: -0.4951; recon_loss: 0.04566
# Iter-10; D_loss: 0.0005236; G_loss: -0.4965; recon_loss: 0.04302
# Iter-0; D_loss: 0.0005937; G_loss: -0.4973; recon_loss: 0.04499
# Iter-10; D_loss: -0.0002905; G_loss: -0.4959; recon_loss: 0.04517
# Iter-0; D_loss: 0.000836; G_loss: -0.4972; recon_loss: 0.0368
# Iter-10; D_loss: 0.003338; G_loss: -0.4992; recon_loss: 0.03163
# Iter-0; D_loss: 0.00243; G_loss: -0.4993; recon_loss: 0.02951
# Iter-10; D_loss: 0.001349; G_loss: -0.4974; recon_loss: 0.03225
# Iter-0; D_loss: 0.002444; G_loss: -0.4978; recon_loss: 0.02558
# Iter-10; D_loss: 0.000971; G_loss: -0.4965; recon_loss: 0.02824
# Iter-0; D_loss: -0.001259; G_loss: -0.4942; recon_loss: 0.02469
# Iter-10; D_loss: -0.0006967; G_loss: -0.494; recon_loss: 0.02238
# Iter-0; D_loss: 0.0002047; G_loss: -0.4967; recon_loss: 0.02424
# Iter-10; D_loss: 0.002773; G_loss: -0.4982; recon_loss: 0.02064
# Iter-0; D_loss: 0.001797; G_loss: -0.4981; recon_loss: 0.02122
# Iter-10; D_loss: 0.0009017; G_loss: -0.4967; recon_loss: 0.02093
# Iter-0; D_loss: -0.002929; G_loss: -0.4926; recon_loss: 0.0176
# Iter-10; D_loss: -0.004115; G_loss: -0.4921; recon_loss: 0.01754
# Iter-0; D_loss: -8.219e-05; G_loss: -0.4953; recon_loss: 0.02336
# Iter-10; D_loss: 0.001809; G_loss: -0.497; recon_loss: 0.01889
# Iter-0; D_loss: -1.189e-05; G_loss: -0.4951; recon_loss: 0.01354
# Iter-10; D_loss: -0.001864; G_loss: -0.4937; recon_loss: 0.01619
# Iter-0; D_loss: 0.0001231; G_loss: -0.4951; recon_loss: 0.01415
# Iter-10; D_loss: 0.001247; G_loss: -0.4971; recon_loss: 0.01471
# Iter-0; D_loss: 0.001089; G_loss: -0.4969; recon_loss: 0.01383
# Iter-10; D_loss: 0.0002029; G_loss: -0.4954; recon_loss: 0.01341
# Iter-0; D_loss: -0.0005205; G_loss: -0.4954; recon_loss: 0.01236
# Iter-10; D_loss: 0.0004789; G_loss: -0.4951; recon_loss: 0.01514
# Iter-0; D_loss: 8.985e-05; G_loss: -0.4955; recon_loss: 0.0115
# Iter-10; D_loss: 0.001388; G_loss: -0.4966; recon_loss: 0.01429
# Iter-0; D_loss: 0.001016; G_loss: -0.4959; recon_loss: 0.01167
# Iter-10; D_loss: 0.0003724; G_loss: -0.4954; recon_loss: 0.01114
# Iter-0; D_loss: -9.531e-05; G_loss: -0.4953; recon_loss: 0.01073
# Iter-10; D_loss: 0.001031; G_loss: -0.4962; recon_loss: 0.01166
# Iter-0; D_loss: 0.0007575; G_loss: -0.4956; recon_loss: 0.0106
# Iter-10; D_loss: 0.0005667; G_loss: -0.4956; recon_loss: 0.0102
# Iter-0; D_loss: -0.0005397; G_loss: -0.4943; recon_loss: 0.01178
# Iter-10; D_loss: -9.203e-05; G_loss: -0.4951; recon_loss: 0.01136
# Iter-0; D_loss: 0.000681; G_loss: -0.4963; recon_loss: 0.01264
# Iter-10; D_loss: 0.0001117; G_loss: -0.4959; recon_loss: 0.01248
# Iter-0; D_loss: -9.069e-05; G_loss: -0.4954; recon_loss: 0.009224
# Iter-10; D_loss: 0.0007728; G_loss: -0.4961; recon_loss: 0.008724
# Iter-0; D_loss: 0.0003827; G_loss: -0.4965; recon_loss: 0.00884
# Iter-10; D_loss: 0.00087; G_loss: -0.4959; recon_loss: 0.008454
# Iter-0; D_loss: 0.0004219; G_loss: -0.4961; recon_loss: 0.009852
# Iter-10; D_loss: -0.0009686; G_loss: -0.4947; recon_loss: 0.009529
# Iter-0; D_loss: -0.0005039; G_loss: -0.4954; recon_loss: 0.008658
# Iter-10; D_loss: 0.0007128; G_loss: -0.4959; recon_loss: 0.009553
# Iter-0; D_loss: 7.451e-07; G_loss: -0.4956; recon_loss: 0.007944
# Iter-10; D_loss: -0.0002033; G_loss: -0.4952; recon_loss: 0.007764
# Iter-0; D_loss: 0.0002993; G_loss: -0.4957; recon_loss: 0.008312
# Iter-10; D_loss: -0.0004397; G_loss: -0.4955; recon_loss: 0.007923
# Iter-0; D_loss: 0.000359; G_loss: -0.4962; recon_loss: 0.007379
# Iter-10; D_loss: 0.0007536; G_loss: -0.4961; recon_loss: 0.007626
# Iter-0; D_loss: 0.0006773; G_loss: -0.4959; recon_loss: 0.008006
# Iter-10; D_loss: -0.0004745; G_loss: -0.4958; recon_loss: 0.007108
# Iter-0; D_loss: -0.0002393; G_loss: -0.4954; recon_loss: 0.009218
# Iter-10; D_loss: 0.0003237; G_loss: -0.4957; recon_loss: 0.007014
# Iter-0; D_loss: 0.001196; G_loss: -0.4964; recon_loss: 0.007429
# Iter-10; D_loss: 0.0008226; G_loss: -0.4964; recon_loss: 0.007758
# Iter-0; D_loss: 3.621e-05; G_loss: -0.4953; recon_loss: 0.00777
# Iter-10; D_loss: -2.426e-05; G_loss: -0.4955; recon_loss: 0.007234
# Iter-0; D_loss: -0.0001956; G_loss: -0.496; recon_loss: 0.005747
# Iter-10; D_loss: 0.0002444; G_loss: -0.4958; recon_loss: 0.007344
# Iter-0; D_loss: -3.368e-05; G_loss: -0.4963; recon_loss: 0.006816
# Iter-10; D_loss: 0.000234; G_loss: -0.4964; recon_loss: 0.005977
# Iter-0; D_loss: 0.0008651; G_loss: -0.4965; recon_loss: 0.007593
# Iter-10; D_loss: 0.000308; G_loss: -0.4965; recon_loss: 0.007083
# Iter-0; D_loss: -0.0002818; G_loss: -0.4961; recon_loss: 0.007824
# Iter-10; D_loss: 0.0003331; G_loss: -0.4959; recon_loss: 0.0066
# Iter-0; D_loss: 3.263e-05; G_loss: -0.4954; recon_loss: 0.005754
# Iter-10; D_loss: -0.0004041; G_loss: -0.4958; recon_loss: 0.005099
# Iter-0; D_loss: -2.676e-05; G_loss: -0.4956; recon_loss: 0.006971
# Iter-10; D_loss: 0.0008032; G_loss: -0.4959; recon_loss: 0.005593
# Iter-0; D_loss: -3.943e-05; G_loss: -0.4959; recon_loss: 0.005564
# Iter-10; D_loss: 0.0003052; G_loss: -0.4962; recon_loss: 0.005693
# Iter-0; D_loss: 0.0002575; G_loss: -0.4964; recon_loss: 0.005779
# Iter-10; D_loss: 0.000213; G_loss: -0.496; recon_loss: 0.004765
# Iter-0; D_loss: -0.0003111; G_loss: -0.4957; recon_loss: 0.006041
# Iter-10; D_loss: 9.707e-05; G_loss: -0.4959; recon_loss: 0.00493
# Iter-0; D_loss: -1.034e-05; G_loss: -0.496; recon_loss: 0.006245
# Iter-10; D_loss: 0.0001342; G_loss: -0.496; recon_loss: 0.005533
# Iter-0; D_loss: 0.0001464; G_loss: -0.496; recon_loss: 0.005259
# Iter-10; D_loss: 0.0001556; G_loss: -0.4965; recon_loss: 0.00479
# Iter-0; D_loss: 0.0002856; G_loss: -0.4964; recon_loss: 0.005545
# Iter-10; D_loss: -0.000129; G_loss: -0.4959; recon_loss: 0.005608
# Iter-0; D_loss: -0.000284; G_loss: -0.496; recon_loss: 0.005501
# Iter-10; D_loss: -0.0003501; G_loss: -0.4959; recon_loss: 0.007095
# Iter-0; D_loss: -0.0006489; G_loss: -0.4957; recon_loss: 0.005298
# Iter-10; D_loss: -0.0007941; G_loss: -0.4959; recon_loss: 0.004868
# Iter-0; D_loss: 8.905e-05; G_loss: -0.4961; recon_loss: 0.004475
# Iter-10; D_loss: -6.303e-05; G_loss: -0.4966; recon_loss: 0.006075
# Iter-0; D_loss: -0.0006169; G_loss: -0.4958; recon_loss: 0.005157
# Iter-10; D_loss: 0.000133; G_loss: -0.4963; recon_loss: 0.004327
# Iter-0; D_loss: 9.733e-05; G_loss: -0.4964; recon_loss: 0.00515
# Iter-10; D_loss: -0.000183; G_loss: -0.4958; recon_loss: 0.004527
# Iter-0; D_loss: -0.0002408; G_loss: -0.4963; recon_loss: 0.004701
# Iter-10; D_loss: -0.0001723; G_loss: -0.496; recon_loss: 0.00515
# Iter-0; D_loss: 0.0001196; G_loss: -0.4964; recon_loss: 0.005012
# Iter-10; D_loss: -0.0003027; G_loss: -0.4961; recon_loss: 0.004053
# Iter-0; D_loss: 0.0001623; G_loss: -0.4962; recon_loss: 0.005099
# Iter-10; D_loss: -0.0004659; G_loss: -0.4959; recon_loss: 0.004323
# Iter-0; D_loss: -0.000645; G_loss: -0.4959; recon_loss: 0.004033
# Iter-10; D_loss: -0.0003343; G_loss: -0.496; recon_loss: 0.005517
# Iter-0; D_loss: 1.422e-05; G_loss: -0.4966; recon_loss: 0.006509
# Iter-10; D_loss: -0.0006765; G_loss: -0.4958; recon_loss: 0.004877
# Iter-0; D_loss: -0.0006924; G_loss: -0.496; recon_loss: 0.005024
# Iter-10; D_loss: -0.000477; G_loss: -0.496; recon_loss: 0.004858
# Iter-0; D_loss: -0.0001079; G_loss: -0.4961; recon_loss: 0.003894
# Iter-10; D_loss: -0.0004886; G_loss: -0.4961; recon_loss: 0.004571
# Iter-0; D_loss: -0.0003979; G_loss: -0.4961; recon_loss: 0.004255
# Iter-10; D_loss: -0.0001051; G_loss: -0.4963; recon_loss: 0.004791
# Iter-0; D_loss: 0.0002294; G_loss: -0.4965; recon_loss: 0.004007
# Iter-10; D_loss: -0.0006714; G_loss: -0.4959; recon_loss: 0.004246
# Iter-0; D_loss: 0.000203; G_loss: -0.4964; recon_loss: 0.004412
# Iter-10; D_loss: -0.0001019; G_loss: -0.4965; recon_loss: 0.00568
# Iter-0; D_loss: -0.000413; G_loss: -0.4964; recon_loss: 0.003437
# Iter-10; D_loss: 0.0001806; G_loss: -0.4966; recon_loss: 0.003581
# Iter-0; D_loss: -0.0004444; G_loss: -0.4964; recon_loss: 0.004239
# Iter-10; D_loss: -0.0004378; G_loss: -0.4963; recon_loss: 0.003603
# Iter-0; D_loss: -0.0002692; G_loss: -0.4966; recon_loss: 0.003948
# Iter-10; D_loss: -0.0004627; G_loss: -0.4964; recon_loss: 0.00451
# Iter-0; D_loss: -0.0003815; G_loss: -0.4964; recon_loss: 0.003567
# Iter-10; D_loss: -0.0002221; G_loss: -0.4964; recon_loss: 0.004053
# Iter-0; D_loss: -0.000349; G_loss: -0.4962; recon_loss: 0.003696
# Iter-10; D_loss: -0.0003384; G_loss: -0.4959; recon_loss: 0.004876
# Iter-0; D_loss: -0.0007916; G_loss: -0.4961; recon_loss: 0.004316
# Iter-10; D_loss: 0.0005299; G_loss: -0.4966; recon_loss: 0.00357
# Iter-0; D_loss: 8.464e-05; G_loss: -0.4967; recon_loss: 0.003024
# Iter-10; D_loss: 0.0003617; G_loss: -0.4967; recon_loss: 0.003806
# Iter-0; D_loss: 0.0001742; G_loss: -0.4965; recon_loss: 0.004293
# Iter-10; D_loss: -0.0005968; G_loss: -0.4959; recon_loss: 0.003701
# Iter-0; D_loss: 0.0001685; G_loss: -0.4966; recon_loss: 0.003415
# Iter-10; D_loss: -0.0002377; G_loss: -0.4968; recon_loss: 0.005003
# Iter-0; D_loss: 0.0002775; G_loss: -0.4969; recon_loss: 0.006098
# Iter-10; D_loss: -0.0001349; G_loss: -0.4964; recon_loss: 0.00373
# Iter-0; D_loss: -0.0006617; G_loss: -0.4961; recon_loss: 0.003941
# Iter-10; D_loss: -0.0005856; G_loss: -0.4966; recon_loss: 0.002787
# Iter-0; D_loss: -0.0002289; G_loss: -0.4967; recon_loss: 0.003557
# Iter-10; D_loss: -0.001086; G_loss: -0.4959; recon_loss: 0.004526
# Iter-0; D_loss: -0.0006388; G_loss: -0.4964; recon_loss: 0.004014
# Iter-10; D_loss: -0.0001493; G_loss: -0.4972; recon_loss: 0.00322
# Iter-0; D_loss: 4.736e-05; G_loss: -0.4972; recon_loss: 0.003679
# Iter-10; D_loss: -0.0008392; G_loss: -0.4964; recon_loss: 0.003868
# Iter-0; D_loss: -0.001296; G_loss: -0.4962; recon_loss: 0.004187
# Iter-10; D_loss: 0.0002269; G_loss: -0.4972; recon_loss: 0.003306
# Iter-0; D_loss: -0.0003206; G_loss: -0.497; recon_loss: 0.003035
# Iter-10; D_loss: 0.00029; G_loss: -0.497; recon_loss: 0.003334
# Iter-0; D_loss: -0.0009642; G_loss: -0.4965; recon_loss: 0.003128
# Iter-10; D_loss: -0.0005699; G_loss: -0.4968; recon_loss: 0.004331
# Iter-0; D_loss: -2.861e-05; G_loss: -0.497; recon_loss: 0.003785
# Iter-10; D_loss: -0.0003054; G_loss: -0.4971; recon_loss: 0.00426
# Iter-0; D_loss: -0.0003795; G_loss: -0.4968; recon_loss: 0.00274
# Iter-10; D_loss: -0.0004311; G_loss: -0.4971; recon_loss: 0.003432
# Iter-0; D_loss: -0.0004939; G_loss: -0.4973; recon_loss: 0.00286
# Iter-10; D_loss: 0.0005629; G_loss: -0.4977; recon_loss: 0.00446
# Iter-0; D_loss: 1.451e-05; G_loss: -0.4972; recon_loss: 0.003766
# Iter-10; D_loss: -0.0005316; G_loss: -0.4973; recon_loss: 0.004103
# Iter-0; D_loss: -0.0004225; G_loss: -0.497; recon_loss: 0.00345
# Iter-10; D_loss: -0.0005749; G_loss: -0.4971; recon_loss: 0.003494
# Iter-0; D_loss: -0.0005575; G_loss: -0.4971; recon_loss: 0.00438
# Iter-10; D_loss: -0.0004538; G_loss: -0.4966; recon_loss: 0.003213
# Iter-0; D_loss: -0.0009623; G_loss: -0.4968; recon_loss: 0.004209
# Iter-10; D_loss: -0.000196; G_loss: -0.4978; recon_loss: 0.004538
# Iter-0; D_loss: -7.212e-05; G_loss: -0.4978; recon_loss: 0.004963
# Iter-10; D_loss: -0.0001671; G_loss: -0.4974; recon_loss: 0.004317
# Iter-0; D_loss: -0.0009885; G_loss: -0.4967; recon_loss: 0.002822
# Iter-10; D_loss: -9.975e-05; G_loss: -0.4972; recon_loss: 0.003371
# Iter-0; D_loss: 0.0004377; G_loss: -0.4978; recon_loss: 0.003418
# Iter-10; D_loss: -0.000172; G_loss: -0.4976; recon_loss: 0.003456
# Iter-0; D_loss: 0.0002687; G_loss: -0.4973; recon_loss: 0.003686
# Iter-10; D_loss: -0.0009142; G_loss: -0.4969; recon_loss: 0.002928
# Iter-0; D_loss: -0.0002409; G_loss: -0.4975; recon_loss: 0.003223
# Iter-10; D_loss: 1.892e-05; G_loss: -0.4971; recon_loss: 0.004287
# Iter-0; D_loss: -0.0005748; G_loss: -0.4972; recon_loss: 0.003485
# Iter-10; D_loss: 9.704e-05; G_loss: -0.4976; recon_loss: 0.00347
# Iter-0; D_loss: 0.0002519; G_loss: -0.4978; recon_loss: 0.003451
# Iter-10; D_loss: -6.449e-05; G_loss: -0.4979; recon_loss: 0.003023
# Iter-0; D_loss: 2.816e-05; G_loss: -0.498; recon_loss: 0.003352
# Iter-10; D_loss: -0.000851; G_loss: -0.4975; recon_loss: 0.003206
# Iter-0; D_loss: -0.0007847; G_loss: -0.4972; recon_loss: 0.005064
# Iter-10; D_loss: 0.0006996; G_loss: -0.4981; recon_loss: 0.002732
# Iter-0; D_loss: 0.000309; G_loss: -0.4984; recon_loss: 0.003025
# Iter-10; D_loss: -0.0001109; G_loss: -0.4979; recon_loss: 0.004053
# Iter-0; D_loss: -0.0006868; G_loss: -0.4973; recon_loss: 0.003157
# Iter-10; D_loss: -0.0004923; G_loss: -0.4976; recon_loss: 0.003274
# Iter-0; D_loss: -0.0003624; G_loss: -0.4979; recon_loss: 0.00291
# Iter-10; D_loss: -4.494e-05; G_loss: -0.4976; recon_loss: 0.00255
# C:\Users\Parth Pankaj Tiwary\Desktop\examples-master\waae\swedish_data\4\
# Iter-0; D_loss: -0.001109; G_loss: -0.5015; recon_loss: 0.1843
# Iter-10; D_loss: 0.006344; G_loss: -0.5082; recon_loss: 0.1327
# Iter-0; D_loss: 0.009421; G_loss: -0.5111; recon_loss: 0.1098
# Iter-10; D_loss: 0.008497; G_loss: -0.5105; recon_loss: 0.09605
# Iter-0; D_loss: 0.005144; G_loss: -0.507; recon_loss: 0.09765
# Iter-10; D_loss: 0.0007637; G_loss: -0.5028; recon_loss: 0.08627
# Iter-0; D_loss: 0.001861; G_loss: -0.5036; recon_loss: 0.08562
# Iter-10; D_loss: 0.001385; G_loss: -0.5033; recon_loss: 0.07843
# Iter-0; D_loss: -0.001593; G_loss: -0.4998; recon_loss: 0.07332
# Iter-10; D_loss: 0.001253; G_loss: -0.5025; recon_loss: 0.06942
# Iter-0; D_loss: 0.001584; G_loss: -0.5037; recon_loss: 0.07536
# Iter-10; D_loss: 0.001576; G_loss: -0.5028; recon_loss: 0.0636
# Iter-0; D_loss: -0.001813; G_loss: -0.5006; recon_loss: 0.05578
# Iter-10; D_loss: -0.001983; G_loss: -0.4999; recon_loss: 0.05958
# Iter-0; D_loss: 0.002484; G_loss: -0.5035; recon_loss: 0.06039
# Iter-10; D_loss: 0.002125; G_loss: -0.5029; recon_loss: 0.05772
# Iter-0; D_loss: -0.001998; G_loss: -0.4987; recon_loss: 0.05512
# Iter-10; D_loss: -0.003515; G_loss: -0.4979; recon_loss: 0.04822
# Iter-0; D_loss: 0.001071; G_loss: -0.5019; recon_loss: 0.05317
# Iter-10; D_loss: 0.0006589; G_loss: -0.5017; recon_loss: 0.04647
# Iter-0; D_loss: 0.0005378; G_loss: -0.5012; recon_loss: 0.04757
# Iter-10; D_loss: -0.001099; G_loss: -0.4995; recon_loss: 0.04367
# Iter-0; D_loss: -0.0006611; G_loss: -0.4997; recon_loss: 0.04732
# Iter-10; D_loss: 1.788e-06; G_loss: -0.5002; recon_loss: 0.04739
# Iter-0; D_loss: -0.001502; G_loss: -0.4999; recon_loss: 0.04127
# Iter-10; D_loss: -0.002145; G_loss: -0.4986; recon_loss: 0.04186
# Iter-0; D_loss: -0.001099; G_loss: -0.4995; recon_loss: 0.0399
# Iter-10; D_loss: -0.0003368; G_loss: -0.5009; recon_loss: 0.03573
# Iter-0; D_loss: 0.0006816; G_loss: -0.501; recon_loss: 0.03387
# Iter-10; D_loss: 0.000186; G_loss: -0.501; recon_loss: 0.03859
# Iter-0; D_loss: -0.0009177; G_loss: -0.5007; recon_loss: 0.03712
# Iter-10; D_loss: 0.0007477; G_loss: -0.5008; recon_loss: 0.03815
# Iter-0; D_loss: 6.515e-05; G_loss: -0.501; recon_loss: 0.03311
# Iter-10; D_loss: 0.000545; G_loss: -0.5009; recon_loss: 0.03163
# Iter-0; D_loss: -0.0004584; G_loss: -0.5002; recon_loss: 0.03586
# Iter-10; D_loss: -0.0004922; G_loss: -0.5007; recon_loss: 0.03476
# Iter-0; D_loss: -0.00149; G_loss: -0.5003; recon_loss: 0.02793
# Iter-10; D_loss: -0.001318; G_loss: -0.4996; recon_loss: 0.02578
# Iter-0; D_loss: -0.001464; G_loss: -0.5002; recon_loss: 0.02753
# Iter-10; D_loss: -0.002145; G_loss: -0.4986; recon_loss: 0.02581
# Iter-0; D_loss: -0.001708; G_loss: -0.4996; recon_loss: 0.0281
# Iter-10; D_loss: -0.001363; G_loss: -0.4999; recon_loss: 0.02523
# Iter-0; D_loss: 0.001025; G_loss: -0.5003; recon_loss: 0.0234
# Iter-10; D_loss: -0.0003969; G_loss: -0.5011; recon_loss: 0.02341
# Iter-0; D_loss: 0.0005327; G_loss: -0.502; recon_loss: 0.0212
# Iter-10; D_loss: -0.0003549; G_loss: -0.5005; recon_loss: 0.02588
# Iter-0; D_loss: -0.0007353; G_loss: -0.5006; recon_loss: 0.01948
# Iter-10; D_loss: 0.0002583; G_loss: -0.5012; recon_loss: 0.01937
# Iter-0; D_loss: -0.0005158; G_loss: -0.501; recon_loss: 0.01974
# Iter-10; D_loss: -0.000809; G_loss: -0.5005; recon_loss: 0.01704
# Iter-0; D_loss: -0.0005735; G_loss: -0.5007; recon_loss: 0.01685
# Iter-10; D_loss: 0.0004964; G_loss: -0.5011; recon_loss: 0.01872
# Iter-0; D_loss: 5.114e-05; G_loss: -0.5011; recon_loss: 0.02411
# Iter-10; D_loss: -0.001057; G_loss: -0.5006; recon_loss: 0.01693
# Iter-0; D_loss: -0.001542; G_loss: -0.4996; recon_loss: 0.0151
# Iter-10; D_loss: 8.804e-05; G_loss: -0.5011; recon_loss: 0.01396
# Iter-0; D_loss: -0.0001178; G_loss: -0.5004; recon_loss: 0.0145
# Iter-10; D_loss: -0.001051; G_loss: -0.5011; recon_loss: 0.01338
# Iter-0; D_loss: -0.0001166; G_loss: -0.5008; recon_loss: 0.01184
# Iter-10; D_loss: -0.0003404; G_loss: -0.5003; recon_loss: 0.01344
# Iter-0; D_loss: 0.0002335; G_loss: -0.5015; recon_loss: 0.01386
# Iter-10; D_loss: 6.3e-05; G_loss: -0.5013; recon_loss: 0.01341
# Iter-0; D_loss: -0.0005941; G_loss: -0.5008; recon_loss: 0.01125
# Iter-10; D_loss: 7.147e-05; G_loss: -0.5009; recon_loss: 0.01336
# Iter-0; D_loss: 0.000356; G_loss: -0.5011; recon_loss: 0.01144
# Iter-10; D_loss: -0.000236; G_loss: -0.501; recon_loss: 0.009901
# Iter-0; D_loss: 0.0001992; G_loss: -0.5011; recon_loss: 0.009401
# Iter-10; D_loss: -0.0009471; G_loss: -0.5005; recon_loss: 0.01057
# Iter-0; D_loss: -0.0002941; G_loss: -0.501; recon_loss: 0.009754
# Iter-10; D_loss: -0.0008262; G_loss: -0.5009; recon_loss: 0.009767
# Iter-0; D_loss: -0.0004484; G_loss: -0.5012; recon_loss: 0.009727
# Iter-10; D_loss: -0.0001828; G_loss: -0.5009; recon_loss: 0.01072
# Iter-0; D_loss: -0.0004886; G_loss: -0.5007; recon_loss: 0.009406
# Iter-10; D_loss: 0.0003098; G_loss: -0.5008; recon_loss: 0.008245
# Iter-0; D_loss: -0.0003549; G_loss: -0.5006; recon_loss: 0.008218
# Iter-10; D_loss: -0.0003608; G_loss: -0.501; recon_loss: 0.009307
# Iter-0; D_loss: 0.0003898; G_loss: -0.5011; recon_loss: 0.007942
# Iter-10; D_loss: -0.0006574; G_loss: -0.5013; recon_loss: 0.006815
# Iter-0; D_loss: -0.0006517; G_loss: -0.501; recon_loss: 0.007814
# Iter-10; D_loss: -0.0001269; G_loss: -0.5013; recon_loss: 0.008337
# Iter-0; D_loss: 0.0002582; G_loss: -0.501; recon_loss: 0.005483
# Iter-10; D_loss: -0.0007654; G_loss: -0.501; recon_loss: 0.006944
# Iter-0; D_loss: -0.0004505; G_loss: -0.5012; recon_loss: 0.006672
# Iter-10; D_loss: -0.0006433; G_loss: -0.5011; recon_loss: 0.00857
# Iter-0; D_loss: -0.0007151; G_loss: -0.5011; recon_loss: 0.006617
# Iter-10; D_loss: -8.19e-05; G_loss: -0.5013; recon_loss: 0.006722
# Iter-0; D_loss: 0.0001901; G_loss: -0.5016; recon_loss: 0.006269
# Iter-10; D_loss: 0.0003386; G_loss: -0.5019; recon_loss: 0.00714
# Iter-0; D_loss: -0.0004949; G_loss: -0.5007; recon_loss: 0.006945
# Iter-10; D_loss: -0.001038; G_loss: -0.5009; recon_loss: 0.007434
# Iter-0; D_loss: -0.0004113; G_loss: -0.501; recon_loss: 0.005799
# Iter-10; D_loss: -0.0005991; G_loss: -0.5009; recon_loss: 0.006515
# Iter-0; D_loss: -0.0001653; G_loss: -0.5012; recon_loss: 0.005831
# Iter-10; D_loss: -7.397e-05; G_loss: -0.5012; recon_loss: 0.007306
# Iter-0; D_loss: -0.000515; G_loss: -0.5008; recon_loss: 0.006066
# Iter-10; D_loss: -0.0005481; G_loss: -0.5008; recon_loss: 0.00685
# Iter-0; D_loss: -0.0003594; G_loss: -0.5007; recon_loss: 0.006513
# Iter-10; D_loss: -0.0007793; G_loss: -0.501; recon_loss: 0.005496
# Iter-0; D_loss: 0.0007715; G_loss: -0.5015; recon_loss: 0.00636
# Iter-10; D_loss: -0.0003542; G_loss: -0.5008; recon_loss: 0.006682
# Iter-0; D_loss: -0.001379; G_loss: -0.4995; recon_loss: 0.005921
# Iter-10; D_loss: -0.001078; G_loss: -0.5001; recon_loss: 0.00475
# Iter-0; D_loss: -0.001065; G_loss: -0.5003; recon_loss: 0.004786
# Iter-10; D_loss: -0.0003208; G_loss: -0.5009; recon_loss: 0.005588
# Iter-0; D_loss: -0.0006359; G_loss: -0.5008; recon_loss: 0.00507
# Iter-10; D_loss: -0.000573; G_loss: -0.5004; recon_loss: 0.005357
# Iter-0; D_loss: -0.0007514; G_loss: -0.5007; recon_loss: 0.004829
# Iter-10; D_loss: -0.0003778; G_loss: -0.5004; recon_loss: 0.004466
# Iter-0; D_loss: -0.0005708; G_loss: -0.5003; recon_loss: 0.005037
# Iter-10; D_loss: -0.0008209; G_loss: -0.5004; recon_loss: 0.005014
# Iter-0; D_loss: -0.0008513; G_loss: -0.5002; recon_loss: 0.004505
# Iter-10; D_loss: -0.0002366; G_loss: -0.5007; recon_loss: 0.004994
# Iter-0; D_loss: -0.0005254; G_loss: -0.5002; recon_loss: 0.005333
# Iter-10; D_loss: -0.0008182; G_loss: -0.5001; recon_loss: 0.00402
# Iter-0; D_loss: -0.000708; G_loss: -0.5001; recon_loss: 0.005177
# Iter-10; D_loss: -0.0005714; G_loss: -0.4998; recon_loss: 0.004866
# Iter-0; D_loss: -0.00103; G_loss: -0.5001; recon_loss: 0.004616
# Iter-10; D_loss: -0.0007821; G_loss: -0.5008; recon_loss: 0.004753
# Iter-0; D_loss: -0.0008113; G_loss: -0.4999; recon_loss: 0.004359
# Iter-10; D_loss: -0.0008636; G_loss: -0.5; recon_loss: 0.005061
# ...
# Iter-10; D_loss: 0.002769; G_loss: -0.5039; recon_loss: 0.05175
# Iter-0; D_loss: 0.0025; G_loss: -0.504; recon_loss: 0.05058
# Iter-10; D_loss: 0.001924; G_loss: -0.5027; recon_loss: 0.0541
# Iter-0; D_loss: 0.002284; G_loss: -0.5036; recon_loss: 0.04807
# Iter-10; D_loss: 0.002851; G_loss: -0.503; recon_loss: 0.03627
# Iter-0; D_loss: -0.001912; G_loss: -0.4989; recon_loss: 0.03341
# Iter-10; D_loss: -0.002346; G_loss: -0.4989; recon_loss: 0.03497
# Iter-0; D_loss: 0.001643; G_loss: -0.502; recon_loss: 0.03876
# Iter-10; D_loss: 0.00077; G_loss: -0.5018; recon_loss: 0.03466
# Iter-0; D_loss: -0.0006942; G_loss: -0.4999; recon_loss: 0.02969
# Iter-10; D_loss: -0.0006259; G_loss: -0.5004; recon_loss: 0.02797
# Iter-0; D_loss: -0.001068; G_loss: -0.4997; recon_loss: 0.02716
# Iter-10; D_loss: 0.0008076; G_loss: -0.5015; recon_loss: 0.02425
# Iter-0; D_loss: 0.001092; G_loss: -0.5015; recon_loss: 0.03014
# Iter-10; D_loss: -0.0001073; G_loss: -0.5003; recon_loss: 0.02264
# Iter-0; D_loss: -0.0006444; G_loss: -0.4988; recon_loss: 0.02175
# Iter-10; D_loss: -0.001428; G_loss: -0.4994; recon_loss: 0.02657
# Iter-0; D_loss: -0.0003741; G_loss: -0.5004; recon_loss: 0.02546
# Iter-10; D_loss: 0.0005676; G_loss: -0.5016; recon_loss: 0.02227
# Iter-0; D_loss: 0.0003068; G_loss: -0.5008; recon_loss: 0.02323
# Iter-10; D_loss: -0.0006232; G_loss: -0.4998; recon_loss: 0.01792
# Iter-0; D_loss: -0.001885; G_loss: -0.4992; recon_loss: 0.02327
# Iter-10; D_loss: -0.0003387; G_loss: -0.5005; recon_loss: 0.01784
# Iter-0; D_loss: -0.001444; G_loss: -0.4995; recon_loss: 0.01401
# Iter-10; D_loss: 0.001339; G_loss: -0.5013; recon_loss: 0.01837
# Iter-0; D_loss: -0.001222; G_loss: -0.4998; recon_loss: 0.01886
# Iter-10; D_loss: 0.001234; G_loss: -0.5009; recon_loss: 0.01864
# Iter-0; D_loss: 0.001579; G_loss: -0.5016; recon_loss: 0.01452
# Iter-10; D_loss: 0.0008487; G_loss: -0.5014; recon_loss: 0.01572
# Iter-0; D_loss: -0.0003099; G_loss: -0.5001; recon_loss: 0.01487
# Iter-10; D_loss: 0.001265; G_loss: -0.501; recon_loss: 0.01578
# Iter-0; D_loss: 1.192e-06; G_loss: -0.5; recon_loss: 0.01323
# Iter-10; D_loss: 0.0004386; G_loss: -0.5008; recon_loss: 0.01268
# Iter-0; D_loss: -0.0003187; G_loss: -0.5; recon_loss: 0.01462
# Iter-10; D_loss: -0.0001135; G_loss: -0.5004; recon_loss: 0.01905
# Iter-0; D_loss: 0.0002353; G_loss: -0.5004; recon_loss: 0.01161
# Iter-10; D_loss: -0.0004854; G_loss: -0.5004; recon_loss: 0.01345
# Iter-0; D_loss: -0.0003298; G_loss: -0.5003; recon_loss: 0.01672
# Iter-10; D_loss: 0.001035; G_loss: -0.501; recon_loss: 0.01414
# Iter-0; D_loss: -0.0005833; G_loss: -0.5006; recon_loss: 0.01213
# Iter-10; D_loss: 0.001057; G_loss: -0.5009; recon_loss: 0.01124
# Iter-0; D_loss: -0.0002149; G_loss: -0.5005; recon_loss: 0.01311
# Iter-10; D_loss: 0.001746; G_loss: -0.5014; recon_loss: 0.01156
# Iter-0; D_loss: 0.0008565; G_loss: -0.5005; recon_loss: 0.01002
# Iter-10; D_loss: 0.0001629; G_loss: -0.5008; recon_loss: 0.008911
# Iter-0; D_loss: 0.0008647; G_loss: -0.5008; recon_loss: 0.008576
# Iter-10; D_loss: 0.0008464; G_loss: -0.5008; recon_loss: 0.01115
# Iter-0; D_loss: 4.542e-05; G_loss: -0.5005; recon_loss: 0.008371
# Iter-10; D_loss: 0.0001026; G_loss: -0.5006; recon_loss: 0.01015
# Iter-0; D_loss: 0.0008023; G_loss: -0.5012; recon_loss: 0.01036
# Iter-10; D_loss: 0.0002611; G_loss: -0.5006; recon_loss: 0.009088
# Iter-0; D_loss: 0.001336; G_loss: -0.5017; recon_loss: 0.008574
# Iter-10; D_loss: 0.0003761; G_loss: -0.5012; recon_loss: 0.01035
# Iter-0; D_loss: 0.0006716; G_loss: -0.5011; recon_loss: 0.00779
# Iter-10; D_loss: 0.0003141; G_loss: -0.5011; recon_loss: 0.008528
# Iter-0; D_loss: -0.0002134; G_loss: -0.501; recon_loss: 0.006636
# Iter-10; D_loss: -0.0006151; G_loss: -0.5007; recon_loss: 0.007312
# Iter-0; D_loss: -0.0004654; G_loss: -0.5004; recon_loss: 0.008671
# Iter-10; D_loss: -0.0005146; G_loss: -0.5006; recon_loss: 0.008229
# Iter-0; D_loss: 0.000136; G_loss: -0.5014; recon_loss: 0.01265
# Iter-10; D_loss: 0.001042; G_loss: -0.5015; recon_loss: 0.008554
# Iter-0; D_loss: 0.0003242; G_loss: -0.5009; recon_loss: 0.007015
# Iter-10; D_loss: 8.464e-05; G_loss: -0.5008; recon_loss: 0.007007
# Iter-0; D_loss: -0.0005586; G_loss: -0.5006; recon_loss: 0.007847
# Iter-10; D_loss: -0.0006441; G_loss: -0.5006; recon_loss: 0.008525
# Iter-0; D_loss: 0.0006484; G_loss: -0.5014; recon_loss: 0.00641
# Iter-10; D_loss: 0.0003925; G_loss: -0.5015; recon_loss: 0.006199
# Iter-0; D_loss: 0.0008706; G_loss: -0.5018; recon_loss: 0.007855
# Iter-10; D_loss: -0.0004224; G_loss: -0.5005; recon_loss: 0.00845
# Iter-0; D_loss: -0.0003614; G_loss: -0.501; recon_loss: 0.006849
# Iter-10; D_loss: -0.0001404; G_loss: -0.5007; recon_loss: 0.006741
# Iter-0; D_loss: 0.0007148; G_loss: -0.5015; recon_loss: 0.006785
# Iter-10; D_loss: 0.0001961; G_loss: -0.5016; recon_loss: 0.007505
# Iter-0; D_loss: 0.0002896; G_loss: -0.5011; recon_loss: 0.007045
# Iter-10; D_loss: -0.0009443; G_loss: -0.5006; recon_loss: 0.006273
# Iter-0; D_loss: -4.59e-05; G_loss: -0.5006; recon_loss: 0.006992
# Iter-10; D_loss: -0.0005485; G_loss: -0.5008; recon_loss: 0.007323
# Iter-0; D_loss: 0.0003748; G_loss: -0.5012; recon_loss: 0.007567
# Iter-10; D_loss: -7.331e-06; G_loss: -0.501; recon_loss: 0.007263
# Iter-0; D_loss: -0.0006318; G_loss: -0.5007; recon_loss: 0.00579
# Iter-10; D_loss: -0.0003656; G_loss: -0.501; recon_loss: 0.006879
# Iter-0; D_loss: 0.0002583; G_loss: -0.5011; recon_loss: 0.006618
# Iter-10; D_loss: -0.0001704; G_loss: -0.5009; recon_loss: 0.005352
# Iter-0; D_loss: 7.033e-05; G_loss: -0.5013; recon_loss: 0.005721
# Iter-10; D_loss: -0.0002356; G_loss: -0.5009; recon_loss: 0.005657
# Iter-0; D_loss: -4.59e-05; G_loss: -0.5013; recon_loss: 0.006166
# Iter-10; D_loss: -0.001148; G_loss: -0.5004; recon_loss: 0.00522
# Iter-0; D_loss: -0.0003225; G_loss: -0.5012; recon_loss: 0.005823
# Iter-10; D_loss: -0.0001866; G_loss: -0.5012; recon_loss: 0.006078
# Iter-0; D_loss: -0.0004098; G_loss: -0.501; recon_loss: 0.006125
# Iter-10; D_loss: -0.000518; G_loss: -0.5009; recon_loss: 0.005661
# Iter-0; D_loss: -0.0005907; G_loss: -0.5007; recon_loss: 0.005218
# Iter-10; D_loss: 0.0007762; G_loss: -0.5017; recon_loss: 0.006639
# Iter-0; D_loss: -1.693e-05; G_loss: -0.5011; recon_loss: 0.006145
# Iter-10; D_loss: -0.00111; G_loss: -0.5007; recon_loss: 0.005742
# Iter-0; D_loss: -0.0007292; G_loss: -0.5006; recon_loss: 0.005358
# Iter-10; D_loss: -0.0009927; G_loss: -0.5007; recon_loss: 0.004466
# Iter-0; D_loss: -0.0007901; G_loss: -0.5006; recon_loss: 0.007355
# Iter-10; D_loss: -0.0008353; G_loss: -0.5011; recon_loss: 0.005005
# Iter-0; D_loss: -0.0002981; G_loss: -0.501; recon_loss: 0.004793
# Iter-10; D_loss: -0.0007849; G_loss: -0.5007; recon_loss: 0.006801
# Iter-0; D_loss: -0.0009521; G_loss: -0.5006; recon_loss: 0.004305
# Iter-10; D_loss: 0.0001886; G_loss: -0.5014; recon_loss: 0.00493
# Iter-0; D_loss: 6.86e-05; G_loss: -0.5018; recon_loss: 0.004965
# Iter-10; D_loss: -0.000237; G_loss: -0.5009; recon_loss: 0.004714
# Iter-0; D_loss: -0.0005272; G_loss: -0.5006; recon_loss: 0.005292
# Iter-10; D_loss: -0.0002083; G_loss: -0.5009; recon_loss: 0.004933
# Iter-0; D_loss: -5.859e-05; G_loss: -0.5011; recon_loss: 0.004388
# Iter-10; D_loss: 2.587e-05; G_loss: -0.5012; recon_loss: 0.00422
# Iter-0; D_loss: -0.0004122; G_loss: -0.501; recon_loss: 0.006136
# Iter-10; D_loss: -0.0008354; G_loss: -0.5004; recon_loss: 0.005171
# Iter-0; D_loss: -0.000609; G_loss: -0.5007; recon_loss: 0.0067
# Iter-10; D_loss: -0.0007132; G_loss: -0.5004; recon_loss: 0.004799
# Iter-0; D_loss: -0.0008228; G_loss: -0.5008; recon_loss: 0.005204
# Iter-10; D_loss: -0.0008828; G_loss: -0.5009; recon_loss: 0.00495
# Iter-0; D_loss: -3.964e-05; G_loss: -0.5009; recon_loss: 0.005074
# Iter-10; D_loss: -0.0004346; G_loss: -0.5008; recon_loss: 0.004916
# Iter-0; D_loss: -0.0004334; G_loss: -0.5007; recon_loss: 0.004347
# Iter-10; D_loss: -0.0006713; G_loss: -0.5005; recon_loss: 0.005231
# Iter-0; D_loss: -0.001241; G_loss: -0.5002; recon_loss: 0.005387
# Iter-10; D_loss: -0.000518; G_loss: -0.5007; recon_loss: 0.004057
# Iter-0; D_loss: -0.001344; G_loss: -0.5003; recon_loss: 0.004373
# Iter-10; D_loss: -0.0007903; G_loss: -0.5005; recon_loss: 0.00446
# Iter-0; D_loss: -0.0004386; G_loss: -0.5007; recon_loss: 0.003881
# Iter-10; D_loss: -0.0003961; G_loss: -0.5006; recon_loss: 0.003616
# Iter-0; D_loss: -0.0005752; G_loss: -0.5007; recon_loss: 0.004316
# Iter-10; D_loss: -0.001098; G_loss: -0.5001; recon_loss: 0.004361
# Iter-0; D_loss: -0.0004091; G_loss: -0.5007; recon_loss: 0.004476
# Iter-10; D_loss: -0.0001675; G_loss: -0.501; recon_loss: 0.003748
# Iter-0; D_loss: -0.0001357; G_loss: -0.5006; recon_loss: 0.003922
# Iter-10; D_loss: 0.0001173; G_loss: -0.5004; recon_loss: 0.004599
# Iter-0; D_loss: -0.000256; G_loss: -0.501; recon_loss: 0.004501
# Iter-10; D_loss: -0.0003771; G_loss: -0.5006; recon_loss: 0.005062
# Iter-0; D_loss: 0.0002708; G_loss: -0.5009; recon_loss: 0.004305
# Iter-10; D_loss: -0.0001433; G_loss: -0.5003; recon_loss: 0.005375
# Iter-0; D_loss: -0.0006819; G_loss: -0.5002; recon_loss: 0.004145
# Iter-10; D_loss: -0.000315; G_loss: -0.5001; recon_loss: 0.0047
# Iter-0; D_loss: -0.000942; G_loss: -0.4999; recon_loss: 0.004094
# Iter-10; D_loss: -0.0006136; G_loss: -0.5004; recon_loss: 0.003501
# Iter-0; D_loss: -0.000384; G_loss: -0.5004; recon_loss: 0.004356
# Iter-10; D_loss: -4.917e-05; G_loss: -0.5008; recon_loss: 0.004249
# Iter-0; D_loss: 0.0003163; G_loss: -0.5011; recon_loss: 0.004165
# Iter-10; D_loss: -0.0002655; G_loss: -0.5006; recon_loss: 0.003695
# Iter-0; D_loss: -0.0002035; G_loss: -0.5004; recon_loss: 0.003887
# Iter-10; D_loss: -0.0009292; G_loss: -0.4999; recon_loss: 0.004785
# Iter-0; D_loss: -0.0007923; G_loss: -0.4995; recon_loss: 0.003982
# Iter-10; D_loss: -0.0009115; G_loss: -0.5003; recon_loss: 0.003768
# Iter-0; D_loss: -0.0001666; G_loss: -0.5008; recon_loss: 0.004046
# Iter-10; D_loss: -0.000623; G_loss: -0.5003; recon_loss: 0.005415
# Iter-0; D_loss: -7.707e-05; G_loss: -0.5003; recon_loss: 0.004936
# Iter-10; D_loss: -0.00103; G_loss: -0.5; recon_loss: 0.00363
# Iter-0; D_loss: -0.000645; G_loss: -0.4998; recon_loss: 0.003289
# Iter-10; D_loss: -0.0008614; G_loss: -0.4996; recon_loss: 0.003678
# Iter-0; D_loss: -0.0007733; G_loss: -0.4997; recon_loss: 0.003798
# Iter-10; D_loss: -5.484e-06; G_loss: -0.5001; recon_loss: 0.003924
# Iter-0; D_loss: -0.0006479; G_loss: -0.4996; recon_loss: 0.003581
# Iter-10; D_loss: 0.0004838; G_loss: -0.5005; recon_loss: 0.004207
# Iter-0; D_loss: 0.0007407; G_loss: -0.5007; recon_loss: 0.00348
# Iter-10; D_loss: -6.324e-05; G_loss: -0.4999; recon_loss: 0.004214
# Iter-0; D_loss: -0.0008784; G_loss: -0.4996; recon_loss: 0.004518
# Iter-10; D_loss: -0.0008052; G_loss: -0.4999; recon_loss: 0.00428
# Iter-0; D_loss: -0.0005526; G_loss: -0.4995; recon_loss: 0.003377
# Iter-10; D_loss: -0.0009018; G_loss: -0.4996; recon_loss: 0.004193
# Iter-0; D_loss: 0.0002025; G_loss: -0.5001; recon_loss: 0.00363
# Iter-10; D_loss: 0.0005798; G_loss: -0.5008; recon_loss: 0.0047
# Iter-0; D_loss: -0.000127; G_loss: -0.5004; recon_loss: 0.003359
# Iter-10; D_loss: -2.39e-05; G_loss: -0.5; recon_loss: 0.00406
# Iter-0; D_loss: -0.001086; G_loss: -0.4994; recon_loss: 0.003957
# Iter-10; D_loss: -0.0005865; G_loss: -0.4998; recon_loss: 0.00351
# Iter-0; D_loss: -0.0004446; G_loss: -0.4998; recon_loss: 0.003217
# Iter-10; D_loss: -0.001206; G_loss: -0.4996; recon_loss: 0.00389
# Iter-0; D_loss: -0.0006361; G_loss: -0.4993; recon_loss: 0.003456
# Iter-10; D_loss: -0.0006126; G_loss: -0.5; recon_loss: 0.003324
# Iter-0; D_loss: -0.0003826; G_loss: -0.5003; recon_loss: 0.003345
# Iter-10; D_loss: 0.0008731; G_loss: -0.5005; recon_loss: 0.003505
# Iter-0; D_loss: -0.0004659; G_loss: -0.5; recon_loss: 0.003351
# Iter-10; D_loss: -0.0005361; G_loss: -0.5; recon_loss: 0.004321
# Iter-0; D_loss: -0.0008902; G_loss: -0.4995; recon_loss: 0.003854
# Iter-10; D_loss: -0.000393; G_loss: -0.4996; recon_loss: 0.003653
# Iter-0; D_loss: -0.0009879; G_loss: -0.4993; recon_loss: 0.003038
# Iter-10; D_loss: -0.0002919; G_loss: -0.4999; recon_loss: 0.003225
# Iter-0; D_loss: -0.0003743; G_loss: -0.5; recon_loss: 0.00363
# Iter-10; D_loss: -0.0003186; G_loss: -0.5; recon_loss: 0.002765
# Iter-0; D_loss: -0.000593; G_loss: -0.4995; recon_loss: 0.00307
# Iter-10; D_loss: -0.0005414; G_loss: -0.4994; recon_loss: 0.003564
# Iter-0; D_loss: 0.0003243; G_loss: -0.5001; recon_loss: 0.003026
# Iter-10; D_loss: -0.001322; G_loss: -0.4993; recon_loss: 0.003964
# Iter-0; D_loss: -0.0008101; G_loss: -0.4992; recon_loss: 0.003693
# Iter-10; D_loss: 0.0004439; G_loss: -0.5001; recon_loss: 0.002993
# Iter-0; D_loss: 0.0003649; G_loss: -0.5006; recon_loss: 0.003183
# Iter-10; D_loss: -0.0009578; G_loss: -0.4991; recon_loss: 0.003301
# C:\Users\Parth Pankaj Tiwary\Desktop\examples-master\waae\swedish_data\7\
# Iter-0; D_loss: -0.001369; G_loss: -0.5007; recon_loss: 0.1928
# Iter-10; D_loss: 0.008133; G_loss: -0.51; recon_loss: 0.1488
# Iter-0; D_loss: 0.01124; G_loss: -0.5116; recon_loss: 0.1376
# Iter-10; D_loss: 0.0088; G_loss: -0.5099; recon_loss: 0.1063
# Iter-0; D_loss: 0.003316; G_loss: -0.5046; recon_loss: 0.0943
# Iter-10; D_loss: 0.001152; G_loss: -0.5018; recon_loss: 0.07725
# Iter-0; D_loss: 0.001696; G_loss: -0.5028; recon_loss: 0.07859
# Iter-10; D_loss: 0.0005655; G_loss: -0.5022; recon_loss: 0.07399
# Iter-0; D_loss: 0.001328; G_loss: -0.5028; recon_loss: 0.06292
# Iter-10; D_loss: -0.0006678; G_loss: -0.5003; recon_loss: 0.05705
# Iter-0; D_loss: 0.0002766; G_loss: -0.501; recon_loss: 0.0547
# Iter-10; D_loss: -0.001187; G_loss: -0.5007; recon_loss: 0.05117
# Iter-0; D_loss: -3.368e-05; G_loss: -0.5012; recon_loss: 0.04863
# Iter-10; D_loss: 0.001231; G_loss: -0.5019; recon_loss: 0.04816
# Iter-0; D_loss: 0.0007664; G_loss: -0.5011; recon_loss: 0.05189
# Iter-10; D_loss: -0.004035; G_loss: -0.4979; recon_loss: 0.04332
# Iter-0; D_loss: -0.001053; G_loss: -0.4995; recon_loss: 0.04643
# Iter-10; D_loss: 0.0001326; G_loss: -0.5012; recon_loss: 0.03145
# Iter-0; D_loss: 0.002488; G_loss: -0.5021; recon_loss: 0.04015
# Iter-10; D_loss: 0.0007131; G_loss: -0.501; recon_loss: 0.03816
# Iter-0; D_loss: -0.002924; G_loss: -0.4985; recon_loss: 0.03239
# Iter-10; D_loss: -0.001309; G_loss: -0.4988; recon_loss: 0.0238
# Iter-0; D_loss: -0.001831; G_loss: -0.4993; recon_loss: 0.02552
# Iter-10; D_loss: -0.0009382; G_loss: -0.5001; recon_loss: 0.02678
# Iter-0; D_loss: -0.0009065; G_loss: -0.5; recon_loss: 0.02707
# Iter-10; D_loss: -0.0005955; G_loss: -0.5007; recon_loss: 0.02706
# Iter-0; D_loss: -0.0007361; G_loss: -0.5002; recon_loss: 0.01863
# Iter-10; D_loss: -0.002126; G_loss: -0.4989; recon_loss: 0.01875
# Iter-0; D_loss: -0.002075; G_loss: -0.4981; recon_loss: 0.02169
# Iter-10; D_loss: -0.003419; G_loss: -0.4979; recon_loss: 0.01716
# Iter-0; D_loss: -0.003365; G_loss: -0.4976; recon_loss: 0.01938
# Iter-10; D_loss: -0.001655; G_loss: -0.4991; recon_loss: 0.016
# Iter-0; D_loss: 0.000596; G_loss: -0.5008; recon_loss: 0.01547
# Iter-10; D_loss: 0.0001092; G_loss: -0.5011; recon_loss: 0.01877
# Iter-0; D_loss: -0.001519; G_loss: -0.4995; recon_loss: 0.01847
# Iter-10; D_loss: -0.002136; G_loss: -0.4997; recon_loss: 0.01453
# Iter-0; D_loss: -0.001052; G_loss: -0.4996; recon_loss: 0.01638
# Iter-10; D_loss: -0.001696; G_loss: -0.4996; recon_loss: 0.01517
# Iter-0; D_loss: -0.002443; G_loss: -0.4996; recon_loss: 0.01421
# Iter-10; D_loss: -0.001825; G_loss: -0.4999; recon_loss: 0.01405
# Iter-0; D_loss: -0.0008449; G_loss: -0.4998; recon_loss: 0.0131
# Iter-10; D_loss: -3.409e-05; G_loss: -0.5009; recon_loss: 0.01478
# Iter-0; D_loss: -0.0007547; G_loss: -0.5; recon_loss: 0.01054
# Iter-10; D_loss: 0.0003841; G_loss: -0.5012; recon_loss: 0.01144
# Iter-0; D_loss: -0.001209; G_loss: -0.4996; recon_loss: 0.01103
# Iter-10; D_loss: -0.0005369; G_loss: -0.5004; recon_loss: 0.01036
# Iter-0; D_loss: -0.001424; G_loss: -0.5001; recon_loss: 0.01437
# Iter-10; D_loss: -0.001767; G_loss: -0.4994; recon_loss: 0.01097
# Iter-0; D_loss: -0.001512; G_loss: -0.4995; recon_loss: 0.01451
# Iter-10; D_loss: -0.0003258; G_loss: -0.5008; recon_loss: 0.01054
# Iter-0; D_loss: -0.001052; G_loss: -0.5003; recon_loss: 0.01055
# Iter-10; D_loss: -0.0004691; G_loss: -0.5007; recon_loss: 0.01043
# Iter-0; D_loss: 0.0002466; G_loss: -0.5009; recon_loss: 0.01068
